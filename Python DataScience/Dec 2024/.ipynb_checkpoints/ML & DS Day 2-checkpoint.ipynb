# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("../datasets/pizza_delivery.csv")

# %%
df.head()
# Out:
#         day       date       time operator branch     driver  temperature  \
# 0  Thursday  01-May-14  35.128367    Laura   East      Bruno    68.287716
# 1  Thursday  01-May-14  25.203074  Melissa   East  Salvatore    70.997791
# 2  Thursday  01-May-14  45.643404  Melissa   West  Salvatore    53.394145
# 3  Thursday  01-May-14  29.374298  Melissa   East  Salvatore    70.306596
# 4  Thursday  01-May-14  29.994610  Melissa   West  Salvatore    71.501688
#
#    bill  pizzas  free_wine  got_wine  discount_customer
# 0  58.4       4          0         0                  1
# 1  26.4       2          0         0                  0
# 2  58.1       3          1         0                  0
# 3  35.2       3          0         0                  0
# 4  38.4       2          0         0                  0

# %% [markdown]
# **Dimensions**

# %%
df.ndim
# Out:
# 2

# %%
df.values
# Out:
# array([['Thursday', '01-May-14', 35.12836705, ..., 0, 0, 1],
#        ['Thursday', '01-May-14', 25.20307368, ..., 0, 0, 0],
#        ['Thursday', '01-May-14', 45.64340414, ..., 1, 0, 0],
#        ...,
#        ['Saturday', '31-May-14', 33.14008002, ..., 0, 0, 1],
#        ['Saturday', '31-May-14', 36.88054621, ..., 0, 0, 1],
#        ['Saturday', '31-May-14', 35.73753383, ..., 0, 0, 0]], dtype=object)

# %%
df.size
# Out:
# 15192

# %%
df.shape
# Out:
# (1266, 12)

# %%
cdf =  df.convert_dtypes()

# %%
cdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1266 entries, 0 to 1265
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   day                1266 non-null   string
#  1   date               1266 non-null   string
#  2   time               1266 non-null   Float64
#  3   operator           1266 non-null   string
#  4   branch             1266 non-null   string
#  5   driver             1266 non-null   string
#  6   temperature        1266 non-null   Float64
#  7   bill               1266 non-null   Float64
#  8   pizzas             1266 non-null   Int64
#  9   free_wine          1266 non-null   Int64
#  10  got_wine           1266 non-null   Int64
#  11  discount_customer  1266 non-null   Int64
# dtypes: Float64(3), Int64(4), string(5)
# memory usage: 127.5 KB

# %%
cdf.select_dtypes("number")
# Out:
#            time  temperature  bill  pizzas  free_wine  got_wine  \
# 0     35.128367    68.287716  58.4       4          0         0
# 1     25.203074    70.997791  26.4       2          0         0
# 2     45.643404    53.394145  58.1       3          1         0
# 3     29.374298    70.306596  35.2       3          0         0
# 4      29.99461    71.501688  38.4       2          0         0
# ...         ...          ...   ...     ...        ...       ...
# 1261   38.63942    63.126424  46.7       4          0         0
# 1262  33.812971    56.302727  32.0       1          0         0
# 1263   33.14008    57.977168  45.7       3          0         0
# 1264  36.880546    52.795834  39.0       5          0         0
# 1265  35.737534    58.642759  42.7       3          0         0
#
#       discount_customer
# 0                     1
# 1                     0
# 2                     0
# 3                     0
# 4                     0
# ...                 ...
# ...

# %%
df.head()
# Out:
#         day       date       time operator branch     driver  temperature  \
# 0  Thursday  01-May-14  35.128367    Laura   East      Bruno    68.287716
# 1  Thursday  01-May-14  25.203074  Melissa   East  Salvatore    70.997791
# 2  Thursday  01-May-14  45.643404  Melissa   West  Salvatore    53.394145
# 3  Thursday  01-May-14  29.374298  Melissa   East  Salvatore    70.306596
# 4  Thursday  01-May-14  29.994610  Melissa   West  Salvatore    71.501688
#
#    bill  pizzas  free_wine  got_wine  discount_customer
# 0  58.4       4          0         0                  1
# 1  26.4       2          0         0                  0
# 2  58.1       3          1         0                  0
# 3  35.2       3          0         0                  0
# 4  38.4       2          0         0                  0

# %%
df.tail()
# Out:
#            day       date       time operator  branch     driver  temperature  \
# 1261  Saturday  31-May-14  38.639420    Laura    West      Mario    63.126424
# 1262  Saturday  31-May-14  33.812971    Laura    East   Domenico    56.302727
# 1263  Saturday  31-May-14  33.140080    Laura  Centre      Luigi    57.977168
# 1264  Saturday  31-May-14  36.880546    Laura  Centre  Salvatore    52.795834
# 1265  Saturday  31-May-14  35.737534  Melissa    West      Bruno    58.642759
#
#       bill  pizzas  free_wine  got_wine  discount_customer
# 1261  46.7       4          0         0                  0
# 1262  32.0       1          0         0                  0
# 1263  45.7       3          0         0                  1
# 1264  39.0       5          0         0                  1
# 1265  42.7       3          0         0                  0

# %%
df.iat[0,8]
# Out:
# 4

# %%
df.at[0,'pizzas']
# Out:
# 4

# %% [markdown]
# **Select specific columns**

# %%
selected_column = ["date", "bill","temperature"]
xdf =  df[selected_column]
xdf
# Out:
#            date  bill  temperature
# 0     01-May-14  58.4    68.287716
# 1     01-May-14  26.4    70.997791
# 2     01-May-14  58.1    53.394145
# 3     01-May-14  35.2    70.306596
# 4     01-May-14  38.4    71.501688
# ...         ...   ...          ...
# 1261  31-May-14  46.7    63.126424
# 1262  31-May-14  32.0    56.302727
# 1263  31-May-14  45.7    57.977168
# 1264  31-May-14  39.0    52.795834
# 1265  31-May-14  42.7    58.642759
#
# [1266 rows x 3 columns]

# %%
xdf.count()
# Out:
# date           1266
# bill           1266
# temperature    1266
# dtype: int64

# %%
selected_column = ["date", "bill","temperature"]
xdf =  df[selected_column]
xdf
# Out:
#            date  bill  temperature
# 0     01-May-14  58.4    68.287716
# 1     01-May-14  26.4    70.997791
# 2     01-May-14  58.1    53.394145
# 3     01-May-14  35.2    70.306596
# 4     01-May-14  38.4    71.501688
# ...         ...   ...          ...
# 1261  31-May-14  46.7    63.126424
# 1262  31-May-14  32.0    56.302727
# 1263  31-May-14  45.7    57.977168
# 1264  31-May-14  39.0    52.795834
# 1265  31-May-14  42.7    58.642759
#
# [1266 rows x 3 columns]

# %%
temp_above_60_filter = xdf['temperature'] > 60
temp_above_60_filter
# Out:
# 0        True
# 1        True
# 2       False
# 3        True
# 4        True
#         ...
# 1261     True
# 1262    False
# 1263    False
# 1264    False
# 1265    False
# Name: temperature, Length: 1266, dtype: bool

# %%
xdf[temp_above_60_filter]
# Out:
#            date  bill  temperature
# 0     01-May-14  58.4    68.287716
# 1     01-May-14  26.4    70.997791
# 3     01-May-14  35.2    70.306596
# 4     01-May-14  38.4    71.501688
# 5     01-May-14  61.8    60.759504
# ...         ...   ...          ...
# 1253  31-May-14  48.5    66.351789
# 1254  31-May-14  38.9    61.445683
# 1255  31-May-14  52.9    64.761225
# 1256  31-May-14  45.6    66.164041
# 1261  31-May-14  46.7    63.126424
#
# [830 rows x 3 columns]

# %%
xdf[xdf["temperature"]>70].count()
# Out:
# date           184
# bill           184
# temperature    184
# dtype: int64

# %%
df.isin([30,40])
# Out:
#         day   date   time  operator  branch  driver  temperature   bill  \
# 0     False  False  False     False   False   False        False  False
# 1     False  False  False     False   False   False        False  False
# 2     False  False  False     False   False   False        False  False
# 3     False  False  False     False   False   False        False  False
# 4     False  False  False     False   False   False        False  False
# ...     ...    ...    ...       ...     ...     ...          ...    ...
# 1261  False  False  False     False   False   False        False  False
# 1262  False  False  False     False   False   False        False  False
# 1263  False  False  False     False   False   False        False  False
# 1264  False  False  False     False   False   False        False  False
# 1265  False  False  False     False   False   False        False  False
#
#       pizzas  free_wine  got_wine  discount_customer
# ...

# %%
df["bill"].isin([10,50]).sum()
# Out:
# 5

# %%
df['bill'].isin([10,50])
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1261    False
# 1262    False
# 1263    False
# 1264    False
# 1265    False
# Name: bill, Length: 1266, dtype: bool

# %%
df[df['pizzas'].isin([5,6,7,8,9])]
# Out:
#            day       date       time operator  branch     driver  temperature  \
# 9     Thursday  01-May-14  37.954792  Melissa  Centre      Bruno    60.007379
# 15    Thursday  01-May-14  40.719208  Melissa    West  Salvatore    71.216953
# 25    Thursday  01-May-14  37.985761  Melissa  Centre      Bruno    49.309722
# 26    Thursday  01-May-14  26.355926    Laura  Centre  Salvatore    68.215742
# 29    Thursday  01-May-14  40.898407  Melissa    West  Salvatore    63.383025
# ...        ...        ...        ...      ...     ...        ...          ...
# 1243  Saturday  31-May-14  21.314470    Laura    East   Domenico    74.902024
# 1244  Saturday  31-May-14  36.735132    Laura    West  Salvatore    56.154315
# 1250  Saturday  31-May-14  34.233622    Laura    West      Bruno    66.914456
# 1251  Saturday  31-May-14  37.866782  Melissa    West      Bruno    56.229618
# 1264  Saturday  31-May-14  36.880546    Laura  Centre  Salvatore    52.795834
#
# ...

# %%
xxdf = xdf.copy()

# %%
xxdf[xxdf["temperature"] > 60] = "Hot"
xxdf.head()
# Out:
#         date  bill temperature
# 0        Hot   Hot         Hot
# 1        Hot   Hot         Hot
# 2  01-May-14  58.1   53.394145
# 3        Hot   Hot         Hot
# 4        Hot   Hot         Hot

# %%
# selecting only 'temerature' column
xxdf = xdf.copy()
xxdf[xxdf["temperature"] > 60]["temperature"] = "Hot"
xxdf.head()
# Out:
# C:\Users\manis\AppData\Local\Temp\ipykernel_21900\3688876829.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   xxdf[xxdf["temperature"] > 60]["temperature"] = "Hot"
#         date  bill  temperature
# 0  01-May-14  58.4    68.287716
# 1  01-May-14  26.4    70.997791
# 2  01-May-14  58.1    53.394145
# 3  01-May-14  35.2    70.306596
# 4  01-May-14  38.4    71.501688

# %% [markdown]
# **Using .loc property to replace all temperature value**

# %%
xxdf = xdf.copy()
xxdf.loc[xxdf["temperature"]>60, "temperature"] = "Hot"
xxdf.head()
# Out:
#         date  bill temperature
# 0  01-May-14  58.4         Hot
# 1  01-May-14  26.4         Hot
# 2  01-May-14  58.1   53.394145
# 3  01-May-14  35.2         Hot
# 4  01-May-14  38.4         Hot

# %%
 s = pd.Series(range(5))

# %%
s
# Out:
# 0    0
# 1    1
# 2    2
# 3    3
# 4    4
# dtype: int64

# %%
s.where(~(s>=3), 'a').where(~(s<3),'b')
# Out:
# 0    b
# 1    b
# 2    b
# 3    a
# 4    a
# dtype: object

# %% [markdown]
# **replacing above 60 by `hot` and below 60 by `cold`**

# %%
temp_cat = df["temperature"]

# %%
hot_cond = temp_cat>60
cold_cond = temp_cat<=60

tc =  temp_cat.where(~hot_cond,"hot").where(~cold_cond,"cold")
tc
# Out:
# 0        hot
# 1        hot
# 2       cold
# 3        hot
# 4        hot
#         ...
# 1261     hot
# 1262    cold
# 1263    cold
# 1264    cold
# 1265    cold
# Name: temperature, Length: 1266, dtype: object

# %%
df.insert(7,"temp_cat",tc)

# %%
df
# Out:
#            day       date       time operator  branch     driver  temperature  \
# 0     Thursday  01-May-14  35.128367    Laura    East      Bruno    68.287716
# 1     Thursday  01-May-14  25.203074  Melissa    East  Salvatore    70.997791
# 2     Thursday  01-May-14  45.643404  Melissa    West  Salvatore    53.394145
# 3     Thursday  01-May-14  29.374298  Melissa    East  Salvatore    70.306596
# 4     Thursday  01-May-14  29.994610  Melissa    West  Salvatore    71.501688
# ...        ...        ...        ...      ...     ...        ...          ...
# 1261  Saturday  31-May-14  38.639420    Laura    West      Mario    63.126424
# 1262  Saturday  31-May-14  33.812971    Laura    East   Domenico    56.302727
# 1263  Saturday  31-May-14  33.140080    Laura  Centre      Luigi    57.977168
# 1264  Saturday  31-May-14  36.880546    Laura  Centre  Salvatore    52.795834
# 1265  Saturday  31-May-14  35.737534  Melissa    West      Bruno    58.642759
#
# ...
