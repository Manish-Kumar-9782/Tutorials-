# %%
import pandas as pd
import numpy as np
df = pd.read_csv("../datasets/pizza_delivery.csv")
df.head()
# Out:
#         day       date       time operator branch     driver  temperature  \
# 0  Thursday  01-May-14  35.128367    Laura   East      Bruno    68.287716
# 1  Thursday  01-May-14  25.203074  Melissa   East  Salvatore    70.997791
# 2  Thursday  01-May-14  45.643404  Melissa   West  Salvatore    53.394145
# 3  Thursday  01-May-14  29.374298  Melissa   East  Salvatore    70.306596
# 4  Thursday  01-May-14  29.994610  Melissa   West  Salvatore    71.501688
#
#    bill  pizzas  free_wine  got_wine  discount_customer
# 0  58.4       4          0         0                  1
# 1  26.4       2          0         0                  0
# 2  58.1       3          1         0                  0
# 3  35.2       3          0         0                  0
# 4  38.4       2          0         0                  0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1266 entries, 0 to 1265
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   day                1266 non-null   object
#  1   date               1266 non-null   object
#  2   time               1266 non-null   float64
#  3   operator           1266 non-null   object
#  4   branch             1266 non-null   object
#  5   driver             1266 non-null   object
#  6   temperature        1266 non-null   float64
#  7   bill               1266 non-null   float64
#  8   pizzas             1266 non-null   int64
#  9   free_wine          1266 non-null   int64
#  10  got_wine           1266 non-null   int64
#  11  discount_customer  1266 non-null   int64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 118.8+ KB

# %%
cols = ['free_wine',"got_wine","discount_customer"]
df[cols] = df[cols].astype("bool")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1266 entries, 0 to 1265
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   day                1266 non-null   object
#  1   date               1266 non-null   object
#  2   time               1266 non-null   float64
#  3   operator           1266 non-null   object
#  4   branch             1266 non-null   object
#  5   driver             1266 non-null   object
#  6   temperature        1266 non-null   float64
#  7   bill               1266 non-null   float64
#  8   pizzas             1266 non-null   int64
#  9   free_wine          1266 non-null   bool
#  10  got_wine           1266 non-null   bool
#  11  discount_customer  1266 non-null   bool
# dtypes: bool(3), float64(3), int64(1), object(5)
# memory usage: 92.8+ KB

# %%
df['pizzas'] = df["pizzas"].astype("int16")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1266 entries, 0 to 1265
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   day                1266 non-null   object
#  1   date               1266 non-null   object
#  2   time               1266 non-null   float64
#  3   operator           1266 non-null   object
#  4   branch             1266 non-null   object
#  5   driver             1266 non-null   object
#  6   temperature        1266 non-null   float64
#  7   bill               1266 non-null   float64
#  8   pizzas             1266 non-null   int16
#  9   free_wine          1266 non-null   bool
#  10  got_wine           1266 non-null   bool
#  11  discount_customer  1266 non-null   bool
# dtypes: bool(3), float64(3), int16(1), object(5)
# memory usage: 85.4+ KB

# %%
cols = ['day','operator','driver','branch']
df[cols] = df[cols].astype("string")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1266 entries, 0 to 1265
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   day                1266 non-null   string
#  1   date               1266 non-null   object
#  2   time               1266 non-null   float64
#  3   operator           1266 non-null   string
#  4   branch             1266 non-null   string
#  5   driver             1266 non-null   string
#  6   temperature        1266 non-null   float64
#  7   bill               1266 non-null   float64
#  8   pizzas             1266 non-null   int16
#  9   free_wine          1266 non-null   bool
#  10  got_wine           1266 non-null   bool
#  11  discount_customer  1266 non-null   bool
# dtypes: bool(3), float64(3), int16(1), object(1), string(4)
# memory usage: 85.4+ KB

# %%
df.head()
# Out:
#         day       date       time operator branch     driver  temperature  \
# 0  Thursday  01-May-14  35.128367    Laura   East      Bruno    68.287716
# 1  Thursday  01-May-14  25.203074  Melissa   East  Salvatore    70.997791
# 2  Thursday  01-May-14  45.643404  Melissa   West  Salvatore    53.394145
# 3  Thursday  01-May-14  29.374298  Melissa   East  Salvatore    70.306596
# 4  Thursday  01-May-14  29.994610  Melissa   West  Salvatore    71.501688
#
#    bill  pizzas  free_wine  got_wine  discount_customer
# 0  58.4       4      False     False               True
# 1  26.4       2      False     False              False
# 2  58.1       3       True     False              False
# 3  35.2       3      False     False              False
# 4  38.4       2      False     False              False

# %%
pd.to_datetime(df['date'], format="%d-%b-%y")
# Out:
# 0      2014-05-01
# 1      2014-05-01
# 2      2014-05-01
# 3      2014-05-01
# 4      2014-05-01
#           ...
# 1261   2014-05-31
# 1262   2014-05-31
# 1263   2014-05-31
# 1264   2014-05-31
# 1265   2014-05-31
# Name: date, Length: 1266, dtype: datetime64[ns]

# %%
df['date'] = pd.to_datetime(df['date'], format="%d-%b-%y")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1266 entries, 0 to 1265
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   day                1266 non-null   string
#  1   date               1266 non-null   datetime64[ns]
#  2   time               1266 non-null   float64
#  3   operator           1266 non-null   string
#  4   branch             1266 non-null   string
#  5   driver             1266 non-null   string
#  6   temperature        1266 non-null   float64
#  7   bill               1266 non-null   float64
#  8   pizzas             1266 non-null   int16
#  9   free_wine          1266 non-null   bool
#  10  got_wine           1266 non-null   bool
#  11  discount_customer  1266 non-null   bool
# dtypes: bool(3), datetime64[ns](1), float64(3), int16(1), string(4)
# memory usage: 85.4 KB

# %%
df.head()
# Out:
#         day       date       time operator branch     driver  temperature  \
# 0  Thursday 2014-05-01  35.128367    Laura   East      Bruno    68.287716
# 1  Thursday 2014-05-01  25.203074  Melissa   East  Salvatore    70.997791
# 2  Thursday 2014-05-01  45.643404  Melissa   West  Salvatore    53.394145
# 3  Thursday 2014-05-01  29.374298  Melissa   East  Salvatore    70.306596
# 4  Thursday 2014-05-01  29.994610  Melissa   West  Salvatore    71.501688
#
#    bill  pizzas  free_wine  got_wine  discount_customer
# 0  58.4       4      False     False               True
# 1  26.4       2      False     False              False
# 2  58.1       3       True     False              False
# 3  35.2       3      False     False              False
# 4  38.4       2      False     False              False

# %%
df =  df.round(2)

# %%
df.head()
# Out:
#         day       date   time operator branch     driver  temperature  bill  \
# 0  Thursday 2014-05-01  35.13    Laura   East      Bruno        68.29  58.4
# 1  Thursday 2014-05-01  25.20  Melissa   East  Salvatore        71.00  26.4
# 2  Thursday 2014-05-01  45.64  Melissa   West  Salvatore        53.39  58.1
# 3  Thursday 2014-05-01  29.37  Melissa   East  Salvatore        70.31  35.2
# 4  Thursday 2014-05-01  29.99  Melissa   West  Salvatore        71.50  38.4
#
#    pizzas  free_wine  got_wine  discount_customer
# 0       4      False     False               True
# 1       2      False     False              False
# 2       3       True     False              False
# 3       3      False     False              False
# 4       2      False     False              False

# %%
from datetime import datetime,date

# %%
today =  datetime.now()

# %%
today.isoweekday()
# Out:
# 3

# %%
df.insert(2,"weekday", df['date'].map(lambda x : x.isoweekday()))

# %%
df.head()
# Out:
#         day       date  weekday   time operator branch     driver  \
# 0  Thursday 2014-05-01        4  35.13    Laura   East      Bruno
# 1  Thursday 2014-05-01        4  25.20  Melissa   East  Salvatore
# 2  Thursday 2014-05-01        4  45.64  Melissa   West  Salvatore
# 3  Thursday 2014-05-01        4  29.37  Melissa   East  Salvatore
# 4  Thursday 2014-05-01        4  29.99  Melissa   West  Salvatore
#
#    temperature  bill  pizzas  free_wine  got_wine  discount_customer
# 0        68.29  58.4       4      False     False               True
# 1        71.00  26.4       2      False     False              False
# 2        53.39  58.1       3       True     False              False
# 3        70.31  35.2       3      False     False              False
# 4        71.50  38.4       2      False     False              False

# %%
df["weekday"].map(lambda x : "weekend" if x >4 else "weekday")
# Out:
# 0       weekday
# 1       weekday
# 2       weekday
# 3       weekday
# 4       weekday
#          ...
# 1261    weekend
# 1262    weekend
# 1263    weekend
# 1264    weekend
# 1265    weekend
# Name: weekday, Length: 1266, dtype: object

# %%
df.insert(2,"day_type", df["weekday"].map(lambda x : "weekend" if x >4 and x<=6 else "weekday"))

# %%
df.head()
# Out:
#         day       date day_type  weekday   time operator branch     driver  \
# 0  Thursday 2014-05-01  weekday        4  35.13    Laura   East      Bruno
# 1  Thursday 2014-05-01  weekday        4  25.20  Melissa   East  Salvatore
# 2  Thursday 2014-05-01  weekday        4  45.64  Melissa   West  Salvatore
# 3  Thursday 2014-05-01  weekday        4  29.37  Melissa   East  Salvatore
# 4  Thursday 2014-05-01  weekday        4  29.99  Melissa   West  Salvatore
#
#    temperature  bill  pizzas  free_wine  got_wine  discount_customer
# 0        68.29  58.4       4      False     False               True
# 1        71.00  26.4       2      False     False              False
# 2        53.39  58.1       3       True     False              False
# 3        70.31  35.2       3      False     False              False
# 4        71.50  38.4       2      False     False              False

# %%
def aggGroupBy(df,groupName, cols, aggfunc):
    groups = df.groupby(groupName)
    return groups.apply(lambda dfx: dfx[cols].agg(aggfunc))

# %%
aggGroupBy(df, 'day_type','bill',"sum") / df['bill'].sum() * 100
# Out:
# day_type
# weekday    61.581962
# weekend    38.418038
# dtype: float64

# %%
aggGroupBy(df, 'day_type',['bill','free_wine','got_wine'],"sum")
# Out:
#              bill  free_wine  got_wine
# day_type
# weekday   33333.7      150.0     117.0
# weekend   20795.3       79.0      71.0

# %%
aggGroupBy(df,'day','bill','sum')
# Out:
# day
# Friday       10477.4
# Monday        5927.8
# Saturday     10317.9
# Sunday        7429.3
# Thursday      8466.8
# Tuesday       5600.8
# Wednesday     5909.0
# dtype: float64

# %%
df["weekday"].isin([5,6]).replace({False: "weekday",True:"weekend"})
# Out:
# 0       weekday
# 1       weekday
# 2       weekday
# 3       weekday
# 4       weekday
#          ...
# 1261    weekend
# 1262    weekend
# 1263    weekend
# 1264    weekend
# 1265    weekend
# Name: weekday, Length: 1266, dtype: object
