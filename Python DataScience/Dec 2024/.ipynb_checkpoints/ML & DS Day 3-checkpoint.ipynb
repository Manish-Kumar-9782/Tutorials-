# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("../datasets/pizza_delivery.csv")

# %%
df.head()
df= df.convert_dtypes()

# %%
df.head()
# Out:
#         day       date       time operator branch     driver  temperature  \
# 0  Thursday  01-May-14  35.128367    Laura   East      Bruno    68.287716
# 1  Thursday  01-May-14  25.203074  Melissa   East  Salvatore    70.997791
# 2  Thursday  01-May-14  45.643404  Melissa   West  Salvatore    53.394145
# 3  Thursday  01-May-14  29.374298  Melissa   East  Salvatore    70.306596
# 4  Thursday  01-May-14   29.99461  Melissa   West  Salvatore    71.501688
#
#    bill  pizzas  free_wine  got_wine  discount_customer
# 0  58.4       4          0         0                  1
# 1  26.4       2          0         0                  0
# 2  58.1       3          1         0                  0
# 3  35.2       3          0         0                  0
# 4  38.4       2          0         0                  0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1266 entries, 0 to 1265
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   day                1266 non-null   string
#  1   date               1266 non-null   string
#  2   time               1266 non-null   Float64
#  3   operator           1266 non-null   string
#  4   branch             1266 non-null   string
#  5   driver             1266 non-null   string
#  6   temperature        1266 non-null   Float64
#  7   bill               1266 non-null   Float64
#  8   pizzas             1266 non-null   Int64
#  9   free_wine          1266 non-null   Int64
#  10  got_wine           1266 non-null   Int64
#  11  discount_customer  1266 non-null   Int64
# dtypes: Float64(3), Int64(4), string(5)
# memory usage: 127.5 KB

# %% [markdown]
# **mean, meadin, mode**

# %%
print("mean of pizzas: ", df["pizzas"].mean())
print("median of pizzas: ", df["pizzas"].median())
print("mode of pizzas: ", df["pizzas"].mode())
# Out:
# mean of pizzas:  3.013428120063191
# median of pizzas:  3.0
# mode of pizzas:  0    2
# Name: pizzas, dtype: Int64

# %%
df.mean(numeric_only=True)
# Out:
# time                 34.229551
# temperature          62.863950
# bill                 42.755924
# pizzas                3.013428
# free_wine             0.180885
# got_wine              0.148499
# discount_customer     0.218009
# dtype: float64

# %%
df.median(numeric_only=True)
# Out:
# time                 34.381964
# temperature          62.926657
# bill                 42.900000
# pizzas                3.000000
# free_wine             0.000000
# got_wine              0.000000
# discount_customer     0.000000
# dtype: float64

# %% [markdown]
# **mod method**

# %%
df["pizzas"].mod(3)
# Out:
# 0       1
# 1       2
# 2       0
# 3       0
# 4       2
#        ..
# 1261    1
# 1262    1
# 1263    0
# 1264    2
# 1265    0
# Name: pizzas, Length: 1266, dtype: Int64

# %% [markdown]
# **std**

# %%
df.std(numeric_only=True)
# Out:
# time                  6.461478
# temperature           6.905708
# bill                 11.222918
# pizzas                1.467102
# free_wine             0.385075
# got_wine              0.355735
# discount_customer     0.413057
# dtype: float64

# %%
df[["time","bill"]].hist(bins=30, figsize=(15,5), sharex=True, sharey=True)
plt.axis([0,80,0,120])
# Out:
# (0.0, 80.0, 0.0, 120.0)

# %%
df.mean(numeric_only=True)
# Out:
# time                 34.229551
# temperature          62.863950
# bill                 42.755924
# pizzas                3.013428
# free_wine             0.180885
# got_wine              0.148499
# discount_customer     0.218009
# dtype: float64

# %%
df.std(numeric_only=True)
# Out:
# time                  6.461478
# temperature           6.905708
# bill                 11.222918
# pizzas                1.467102
# free_wine             0.385075
# got_wine              0.355735
# discount_customer     0.413057
# dtype: float64

# %%
df.var(numeric_only=True)
# Out:
# time                  41.750699
# temperature           47.688798
# bill                 125.953882
# pizzas                 2.152389
# free_wine              0.148283
# got_wine               0.126547
# discount_customer      0.170616
# dtype: float64

# %%
df.head()
# Out:
#         day       date       time operator branch     driver  temperature  \
# 0  Thursday  01-May-14  35.128367    Laura   East      Bruno    68.287716
# 1  Thursday  01-May-14  25.203074  Melissa   East  Salvatore    70.997791
# 2  Thursday  01-May-14  45.643404  Melissa   West  Salvatore    53.394145
# 3  Thursday  01-May-14  29.374298  Melissa   East  Salvatore    70.306596
# 4  Thursday  01-May-14   29.99461  Melissa   West  Salvatore    71.501688
#
#    bill  pizzas  free_wine  got_wine  discount_customer
# 0  58.4       4          0         0                  1
# 1  26.4       2          0         0                  0
# 2  58.1       3          1         0                  0
# 3  35.2       3          0         0                  0
# 4  38.4       2          0         0                  0

# %%
df.min(numeric_only=True)
# Out:
# time                 12.266028
# temperature          41.758718
# bill                  9.100000
# pizzas                1.000000
# free_wine             0.000000
# got_wine              0.000000
# discount_customer     0.000000
# dtype: float64

# %%
df.max(numeric_only=True)
# Out:
# time                 53.096264
# temperature          87.582422
# bill                 75.000000
# pizzas               11.000000
# free_wine             1.000000
# got_wine              1.000000
# discount_customer     1.000000
# dtype: float64

# %%
df.sum(numeric_only=True).round(2)
# Out:
# time                 43334.61
# temperature          79585.76
# bill                 54129.00
# pizzas                3815.00
# free_wine              229.00
# got_wine               188.00
# discount_customer      276.00
# dtype: float64

# %%
df.count(numeric_only=True)
# Out:
# time                 1266
# temperature          1266
# bill                 1266
# pizzas               1266
# free_wine            1266
# got_wine             1266
# discount_customer    1266
# dtype: int64

# %%
df.describe()
# Out:
#             time  temperature       bill    pizzas  free_wine  got_wine  \
# count     1266.0       1266.0     1266.0    1266.0     1266.0    1266.0
# mean   34.229551     62.86395  42.755924  3.013428   0.180885  0.148499
# std     6.461478     6.905708  11.222918  1.467102   0.385075  0.355735
# min    12.266028    41.758718        9.1       1.0        0.0       0.0
# 25%    30.061151    58.242364       35.5       2.0        0.0       0.0
# 50%    34.381964    62.926657       42.9       3.0        0.0       0.0
# 75%    38.577021    67.228628       50.5       4.0        0.0       0.0
# max    53.096264    87.582422       75.0      11.0        1.0       1.0
#
#        discount_customer
# count             1266.0
# mean            0.218009
# std             0.413057
# min                  0.0
# 25%                  0.0
# 50%                  0.0
# 75%                  0.0
# max                  1.0

# %%
df.quantile(0.25, numeric_only=True)
# Out:
# time                 30.061151
# temperature          58.242364
# bill                      35.5
# pizzas                     2.0
# free_wine                  0.0
# got_wine                   0.0
# discount_customer          0.0
# Name: 0.25, dtype: Float64

# %%
#df.prod(numeric_only=True)

# %%
test_df = pd.DataFrame({'Numbers': [2, 3, 4]})

# %%
test_df.prod()
# Out:
# Numbers    24
# dtype: int64

# %%
df['driver'].unique()
# Out:
# <StringArray>
# ['Bruno', 'Salvatore', 'Mario', 'Luigi', 'Domenico']
# Length: 5, dtype: string

# %%
df.driver.nunique()
# Out:
# 5

# %% [markdown]
# **value_counts**

# %%
df["pizzas"].value_counts()
# Out:
# pizzas
# 2     344
# 3     337
# 4     232
# 1     174
# 5     104
# 6      47
# 7      19
# 9       4
# 8       4
# 11      1
# Name: count, dtype: Int64

# %%
df.value_counts("pizzas", normalize=True)
# Out:
# pizzas
# 2     0.271722
# 3     0.266193
# 4     0.183254
# 1     0.137441
# 5     0.082148
# 6     0.037125
# 7     0.015008
# 8     0.003160
# 9     0.003160
# 11    0.000790
# Name: proportion, dtype: float64

# %%
df.value_counts("pizzas", normalize=True).plot(kind='pie')
# Out:
# <Axes: ylabel='proportion'>

# %% [markdown]
# **groupby method**

# %%
df.groupby("driver").mean(numeric_only=True)
# Out:
#                 time  temperature       bill    pizzas  free_wine  got_wine  \
# driver
# Bruno      35.312789     61.87884  44.634347  3.179331   0.231003   0.18845
# Domenico   29.316396    68.440683  33.288172  2.172043   0.064516  0.043011
# Luigi      33.378939    63.597334   41.06338  2.746479   0.119718  0.098592
# Mario      34.461045    62.755229  42.917877  2.932961   0.170391  0.136872
# Salvatore  34.632025    62.108852  44.049128  3.276163   0.200581  0.171512
#
#            discount_customer
# driver
# Bruno                0.18541
# Domenico            0.236559
# Luigi               0.288732
# Mario               0.215084
# Salvatore           0.218023
