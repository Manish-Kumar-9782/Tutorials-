# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import norm

# %%
df = pd.read_csv("../datasets/pizza_delivery.csv")

# %%
df.head()
# Out:
#         day       date       time operator branch     driver  temperature  \
# 0  Thursday  01-May-14  35.128367    Laura   East      Bruno    68.287716
# 1  Thursday  01-May-14  25.203074  Melissa   East  Salvatore    70.997791
# 2  Thursday  01-May-14  45.643404  Melissa   West  Salvatore    53.394145
# 3  Thursday  01-May-14  29.374298  Melissa   East  Salvatore    70.306596
# 4  Thursday  01-May-14  29.994610  Melissa   West  Salvatore    71.501688
#
#    bill  pizzas  free_wine  got_wine  discount_customer
# 0  58.4       4          0         0                  1
# 1  26.4       2          0         0                  0
# 2  58.1       3          1         0                  0
# 3  35.2       3          0         0                  0
# 4  38.4       2          0         0                  0

# %%
df["bill"].hist(bins=30)
# Out:
# <Axes: >

# %%
df["bill"].plot(kind='kde', xlim=(0,80))
# Out:
# <Axes: ylabel='Density'>

# %%
(df["bill"].min(), df["bill"].max())
# Out:
# (9.1, 75.0)

# %%
std_1 = (df.bill.mean()-df.bill.std(), df.bill.mean()+df.bill.std()) 
std_1
# Out:
# (31.53300646297403, 53.978841878258194)

# %%
axes = df["bill"].plot(kind='kde', xlim=(0,80))
pdf= norm.pdf(df.bill, scale=11.22, loc=42.7)

std_1 = (df.bill.mean()-df.bill.std(), df.bill.mean()+df.bill.std())
std_2 = (df.bill.mean()-2*df.bill.std(), df.bill.mean()+2*df.bill.std())
std_3 = (df.bill.mean()-3*df.bill.std(), df.bill.mean()+3*df.bill.std())

# axes.scatter(df.bill, pdf)

axes.vlines(std_1, 0, .02, color='green')
axes.vlines(std_2, 0, .04, color='orange')
axes.vlines(std_3, 0, .03, color='red')

plt.show()

# %% [markdown]
# **point on normal curve**

# %%
pdf= norm.pdf(df.bill, scale=11.22, loc=42.7)
pdf
# Out:
# array([0.01335802, 0.01237723, 0.01386231, ..., 0.03430781, 0.03367465,
#        0.03555635])

# %%
df.bill.std()
# Out:
# 11.222917707642083

# %%
pdf_points =  pd.DataFrame({"Point": df.bill, "Density Point": pdf}).sort_values("Point")
pdf_points
# Out:
#       Point  Density Point
# 770     9.1       0.000401
# 258    10.6       0.000594
# 72     10.8       0.000625
# 535    11.6       0.000763
# 520    11.9       0.000821
# ...     ...            ...
# 1257   71.3       0.001380
# 803    71.7       0.001260
# 385    71.9       0.001203
# 422    74.0       0.000726
# 842    75.0       0.000564
#
# [1266 rows x 2 columns]

# %%
pdf_points[(pdf_points["Point"]>30) & (pdf_points["Point"]<32)]
# Out:
#       Point  Density Point
# 150    30.1       0.018926
# 426    30.1       0.018926
# 260    30.2       0.019116
# 1054   30.3       0.019306
# 612    30.3       0.019306
# 450    30.4       0.019496
# 625    30.4       0.019496
# 898    30.4       0.019496
# 191    30.4       0.019496
# 953    30.4       0.019496
# 589    30.5       0.019687
# 652    30.6       0.019878
# 142    30.6       0.019878
# 602    30.7       0.020069
# 1019   30.7       0.020069
# 722    30.8       0.020261
# 689    30.8       0.020261
# 199    30.8       0.020261
# 1140   30.9       0.020452
# 186    31.0       0.020644
# 1205   31.0       0.020644
# 713    31.0       0.020644
# 486    31.1       0.020836
# 905    31.1       0.020836
# 560    31.1       0.020836
# 276    31.2       0.021028
# 361    31.2       0.021028
# 892    31.3       0.021220
# 551    31.3       0.021220
# 21     31.3       0.021220
# 139    31.3       0.021220
# 524    31.4       0.021412
# 124    31.4       0.021412
# 1258   31.4       0.021412
# 1236   31.5       0.021604
# 737    31.5       0.021604
# 933    31.6       0.021797
# 303    31.6       0.021797
# 1123   31.6       0.021797
# 336    31.7       0.021989
# 307    31.7       0.021989
# 688    31.7       0.021989
# 871    31.7       0.021989
# 418    31.7       0.021989
# 100    31.7       0.021989
# 1216   31.8       0.022181
# 653    31.8       0.022181
# 98     31.8       0.022181
# 738    31.8       0.022181
# 708    31.8       0.022181
# 83     31.9       0.022373
# 259    31.9       0.022373
# 849    31.9       0.022373
# 383    31.9       0.022373
# 423    31.9       0.022373

# %% [markdown]
# ____

# %% [markdown]
# ## Standard Normal Distribution
#
# In Tina's section the mean was 64 and her score was 74. In Jack's section the
# was 72 and his score was 82. Both Tina and Jack pleased that their scores were
# each 10 points above the average of each respective section.

# %%
tina_section = {
    'mean': 64,
    'score':74,
    'std': 5
}

jack_section = {
    'mean': 72,
    'score':82,
    'std': 10
}

# %%
tina_section_scores= np.random.normal(tina_section["mean"], tina_section["std"], 3000)
jack_section_scores = np.random.normal(jack_section["mean"], jack_section['std'], 3000)

# %%
sections = pd.DataFrame({
    "tina_section": tina_section_scores,
    "jack_section": jack_section_scores
})

# %%
fig , axes = plt.subplots(ncols=2, figsize=(15,6))


axes1, axes2 = axes
sections.tina_section.plot(kind="kde", ax=axes[0] , 
             xlim=(sections.tina_section.min(), sections.tina_section.max()) )
sections.jack_section.plot(kind="kde", ax=axes[1],
            xlim= (sections.jack_section.min(), sections.jack_section.max()))

axes1.set_title("tina section")
axes2.set_title("jack section")


# mean score
axes1.vlines(tina_section['mean'], 0,0.07, color='yellow' )
axes2.vlines(jack_section['mean'], 0,0.035, color='yellow')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [43], line 13
#       9 axes2.set_title("jack section")
#      12 # mean score
# ---> 13 axes1.vlines(tina_section['mean'], 0,0.07, color='yellow' ,
#      14              xlim=(sections.tina_section.min(), sections.tina_section.max()) )
#      15 axes2.vlines(jack_section['mean'], 0,0.035, color='yellow',
#      16             xlim= (sections.jack_section.min(), sections.jack_section.max()))
#      18 plt.show()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\__init__.py:1461, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1458 @functools.wraps(func)
#    1459 def inner(ax, *args, data=None, **kwargs):
#    1460     if data is None:
# -> 1461         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1463     bound = new_sig.bind(ax, *args, **kwargs)
#    1464     auto_label = (bound.arguments.get(label_namer)
#    1465                   or bound.kwargs.get(label_namer))
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\axes\_axes.py:1177, in Axes.vlines(self, x, ymin, ymax, colors, linestyles, label, **kwargs)
#    1174 lines = mcoll.LineCollection(masked_verts, colors=colors,
#    1175                              linestyles=linestyles, label=label)
#    1176 self.add_collection(lines, autolim=False)
# -> 1177 lines._internal_update(kwargs)
#    1179 if len(x) > 0:
#    1180     # Extreme values of x/ymin/ymax.  Using masked_verts here handles
#    1181     # the case of x being a masked *object* array (as can be generated
#    1182     # e.g. by errorbar()), which would make nanmin/nanmax stumble.
#    1183     minx = np.nanmin(masked_verts[..., 0])
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\artist.py:1223, in Artist._internal_update(self, kwargs)
#    1216 def _internal_update(self, kwargs):
#    1217     """
#    1218     Update artist properties without prenormalizing them, but generating
#    1219     errors as if calling `set`.
#    1220
#    1221     The lack of prenormalization is to maintain backcompatibility.
#    1222     """
# -> 1223     return self._update_props(
#    1224         kwargs, "{cls.__name__}.set() got an unexpected keyword argument "
#    1225         "{prop_name!r}")
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\artist.py:1197, in Artist._update_props(self, props, errfmt)
#    1195             func = getattr(self, f"set_{k}", None)
#    1196             if not callable(func):
# -> 1197                 raise AttributeError(
#    1198                     errfmt.format(cls=type(self), prop_name=k))
#    1199             ret.append(func(v))
#    1200 if ret:
#
# AttributeError: LineCollection.set() got an unexpected keyword argument 'xlim'
