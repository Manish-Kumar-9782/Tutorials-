# %% [markdown]
# # Life Expectancy

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("../datasets/Life Expectancy Data.csv")

# %%
df.head()
# Out:
#        Country  Year      Status  Life expectancy   Adult Mortality  \
# 0  Afghanistan  2015  Developing              65.0            263.0
# 1  Afghanistan  2014  Developing              59.9            271.0
# 2  Afghanistan  2013  Developing              59.9            268.0
# 3  Afghanistan  2012  Developing              59.5            272.0
# 4  Afghanistan  2011  Developing              59.2            275.0
#
#    infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   ...  \
# 0             62     0.01               71.279624         65.0      1154  ...
# 1             64     0.01               73.523582         62.0       492  ...
# 2             66     0.01               73.219243         64.0       430  ...
# 3             69     0.01               78.184215         67.0      2787  ...
# 4             71     0.01                7.097109         68.0      3013  ...
#
#    Polio  Total expenditure  Diphtheria    HIV/AIDS         GDP  Population  \
# 0    6.0               8.16         65.0        0.1  584.259210  33736494.0
# 1   58.0               8.18         62.0        0.1  612.696514    327582.0
# 2   62.0               8.13         64.0        0.1  631.744976  31731688.0
# 3   67.0               8.52         67.0        0.1  669.959000   3696958.0
# 4   68.0               7.87         68.0        0.1   63.537231   2978599.0
#
#     thinness  1-19 years   thinness 5-9 years  \
# 0                   17.2                 17.3
# 1                   17.5                 17.5
# 2                   17.7                 17.7
# 3                   17.9                 18.0
# 4                   18.2                 18.2
#
#    Income composition of resources  Schooling
# 0                            0.479       10.1
# 1                            0.476       10.0
# 2                            0.470        9.9
# 3                            0.463        9.8
# 4                            0.454        9.5
#
# [5 rows x 22 columns]

# %%
df.columns  = [x.strip()  for x in df.columns]

# %%
df.columns
# Out:
# Index(['Country', 'Year', 'Status', 'Life expectancy', 'Adult Mortality',
#        'infant deaths', 'Alcohol', 'percentage expenditure', 'Hepatitis B',
#        'Measles', 'BMI', 'under-five deaths', 'Polio', 'Total expenditure',
#        'Diphtheria', 'HIV/AIDS', 'GDP', 'Population', 'thinness  1-19 years',
#        'thinness 5-9 years', 'Income composition of resources', 'Schooling'],
#       dtype='object')

# %%
df_2 = df[["Year","Country","Life expectancy", "Alcohol", "Schooling", "GDP", "BMI", "Population"]].copy()

# %%
df_2.head()
# Out:
#    Year      Country  Life expectancy  Alcohol  Schooling         GDP   BMI  \
# 0  2015  Afghanistan             65.0     0.01       10.1  584.259210  19.1
# 1  2014  Afghanistan             59.9     0.01       10.0  612.696514  18.6
# 2  2013  Afghanistan             59.9     0.01        9.9  631.744976  18.1
# 3  2012  Afghanistan             59.5     0.01        9.8  669.959000  17.6
# 4  2011  Afghanistan             59.2     0.01        9.5   63.537231  17.2
#
#    Population
# 0  33736494.0
# 1    327582.0
# 2  31731688.0
# 3   3696958.0
# 4   2978599.0

# %%
df_2["Life expectancy"].plot.hist(xlabel="Life expectancy")
# Out:
# <Axes: xlabel='Life expectancy', ylabel='Frequency'>

# %%
df_2.sort_values("Life expectancy", inplace=True)
df_2.dropna(inplace=True)

# %%
fig, axes = plt.subplots()
axes.plot(df_2["Life expectancy"], df_2["Alcohol"])
axes.set_xlabel("Life Expectancy")
axes.set_ylabel("Alcohol")

plt.show()

# %%
def plot_life(df, xlabel, ylabel):
    fig, axes = plt.subplots()

    axes.plot(df[xlabel], df[ylabel])
    axes.set_xlabel(xlabel)
    axes.set_ylabel(ylabel)
    plt.title(f"{xlabel} vs {ylabel}")
    plt.show()

# %% [markdown]
# ## On sample

# %%
sample_df = df_2.sample(frac= 0.30)
sample_df.sort_values("Life expectancy", inplace=True)

# %%
plot_life(sample_df, "Life expectancy", "Alcohol")

# %%
# gdp vs life expectancy
plot_life(sample_df, "Life expectancy", "GDP")

# %%
df_2[["Alcohol", "GDP"]].apply("mean")
# Out:
# Alcohol       4.735523
# GDP        6718.208281
# dtype: float64

# %%
fig, axes = plt.subplots()

axes.scatter(df_2["Life expectancy"], df_2["Alcohol"])
axes.set_xlabel("Life Expectancy")
axes.set_ylabel("Alcohol")

plt.show()

# %%
df_2["Alcohol"].corr(df_2["Life expectancy"])
# Out:
# 0.42947640242801544

# %%
def plot_scatter(x,y,xlabel,ylabel,ax):
    ax.scatter(x, y)
    ax.set_xlabel(xlabel)
    ax.set_ylabel(ylabel)

def plot_hist(x, xlabel,  ax):
    ax.hist(x)
    ax.set_ylabel(f"Frequency of {xlabel}")
    ax.set_xlabel(xlabel)

# %%
fig, axes = plt.subplots(figsize=(15,9), nrows=2, ncols=3)

axes = axes.flatten()

columns = df_2.columns[2:]

for ax, col in zip(axes, columns):
    plot_scatter(df_2["Life expectancy"], df_2[col], xlabel="Life Expectancy", ylabel=col, ax=ax)

plt.show()

# %%
fig, (axes1, axes2) = plt.subplots(ncols=2, figsize=(15, 6))

axes1.scatter(df_2["Life expectancy"], df_2["GDP"])
axes1.set_xlabel("Life Expectancy")
axes1.set_ylabel("GDP")
axes1.set_yscale('log')

axes2.scatter(df_2["Life expectancy"], df_2["GDP"])
axes2.set_xlabel("Life Expectancy")
axes2.set_ylabel("GDP")
# axes1.set_yscale('log')


plt.show()

# %%
df_2["Life expectancy"].corr(df_2["GDP"])
# Out:
# 0.4658779090204914

# %%
fig, (axes1, axes2) = plt.subplots(ncols=2, figsize=(15, 6))

axes1.scatter(df_2["Life expectancy"], df_2["Population"])
axes1.set_xlabel("Life Expectancy")
axes1.set_ylabel("Population")
axes1.set_yscale('log')

axes2.scatter(df_2["Life expectancy"], df_2["Population"])
axes2.set_xlabel("Life Expectancy")
axes2.set_ylabel("Population")
# axes1.set_yscale('log')


plt.show()

# %%
df_2["Life expectancy"].corr(df_2["Population"])
# Out:
# -0.022290170598343373

# %%
axes.flatten()
# Out:
# array([<Axes: xlabel='Life Expectancy', ylabel='Life expectancy'>,
#        <Axes: xlabel='Life Expectancy', ylabel='Alcohol'>,
#        <Axes: xlabel='Life Expectancy', ylabel='Schooling'>,
#        <Axes: xlabel='Life Expectancy', ylabel='GDP'>,
#        <Axes: xlabel='Life Expectancy', ylabel='BMI'>,
#        <Axes: xlabel='Life Expectancy', ylabel='Population'>],
#       dtype=object)

# %%
fig, axes = plt.subplots(figsize=(15,9), nrows=2, ncols=3)

axes = axes.flatten()

columns = df_2.columns[2:]

for ax, col in zip(axes, columns):
    plot_hist(df_2[col],col,ax)

plt.show()

# %%
df_2[df_2.columns[2:]].corr()
# Out:
#                  Life expectancy   Alcohol  Schooling       GDP       BMI  \
# Life expectancy         1.000000  0.429476   0.766093  0.465878  0.597622
# Alcohol                 0.429476  1.000000   0.613785  0.453141  0.399224
# Schooling               0.766093  0.613785   1.000000  0.488471  0.587797
# GDP                     0.465878  0.453141   0.488471  1.000000  0.306717
# BMI                     0.597622  0.399224   0.587797  0.306717  1.000000
# Population             -0.022290 -0.035201  -0.037053 -0.030613 -0.075246
#
#                  Population
# Life expectancy   -0.022290
# Alcohol           -0.035201
# Schooling         -0.037053
# GDP               -0.030613
# BMI               -0.075246
# Population         1.000000

# %%
df.head()
# Out:
#        Country  Year      Status  Life expectancy  Adult Mortality  \
# 0  Afghanistan  2015  Developing             65.0            263.0
# 1  Afghanistan  2014  Developing             59.9            271.0
# 2  Afghanistan  2013  Developing             59.9            268.0
# 3  Afghanistan  2012  Developing             59.5            272.0
# 4  Afghanistan  2011  Developing             59.2            275.0
#
#    infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles  ...  \
# 0             62     0.01               71.279624         65.0     1154  ...
# 1             64     0.01               73.523582         62.0      492  ...
# 2             66     0.01               73.219243         64.0      430  ...
# 3             69     0.01               78.184215         67.0     2787  ...
# 4             71     0.01                7.097109         68.0     3013  ...
#
#    Polio  Total expenditure  Diphtheria  HIV/AIDS         GDP  Population  \
# 0    6.0               8.16        65.0       0.1  584.259210  33736494.0
# 1   58.0               8.18        62.0       0.1  612.696514    327582.0
# 2   62.0               8.13        64.0       0.1  631.744976  31731688.0
# 3   67.0               8.52        67.0       0.1  669.959000   3696958.0
# 4   68.0               7.87        68.0       0.1   63.537231   2978599.0
#
#    thinness  1-19 years  thinness 5-9 years  Income composition of resources  \
# 0                  17.2                17.3                            0.479
# 1                  17.5                17.5                            0.476
# 2                  17.7                17.7                            0.470
# 3                  17.9                18.0                            0.463
# 4                  18.2                18.2                            0.454
#
#    Schooling
# 0       10.1
# 1       10.0
# 2        9.9
# 3        9.8
# 4        9.5
#
# [5 rows x 22 columns]

# %%
gdp_summary =  df_2.pivot(index="Country", columns="Year", values="GDP")

# %%
gdp_summary.T
# Out:
# Country  Afghanistan      Albania      Algeria       Angola     Argentina  \
# Year
# 2000      114.560000  1175.788981  1757.177970   555.296942   7669.273916
# 2001      117.496980  1326.973390  1732.857979   526.168743    717.694674
# 2002      187.845950  1453.642777  1774.336730   711.181716   2579.193168
# 2003      198.728544   189.681557   294.335560   779.468356    333.437600
# 2004      219.141353  2416.588235  2598.982300   141.868440   4251.574348
# 2005       25.294130   279.142931    31.122378  1443.991929    576.883829
# 2006      272.563770    35.129300  3464.617900   262.415149   5878.761270
# 2012     4137.554210   1172.384300   6675.262954  647.747410  3855.421280
# 2013     4199.472530  12542.935650    734.425250  662.492293   429.715540
# 2014     4271.681720  12127.225220   7962.365824  719.172669   314.658296
# 2015             NaN           NaN           NaN         NaN          NaN
#
# Country       Uruguay   Uzbekistan      Vanuatu       Zambia    Zimbabwe
# Year
# 2000      6871.897677   558.221144  1469.849149   341.955625  547.358878
# 2001      6281.377470   456.734892  1362.617310   378.273624  548.587312
# 2002       488.768855   383.349500  1353.934819   377.135244   57.348340
# 2003      3622.522840   396.129969   158.527240   429.158343  453.351155
# 2004      4117.388530   465.119887  1787.947230    53.277222  454.366654
# 2005       522.951116   546.776852  1886.433359   691.317816  444.765750
# 2006      5877.876780   654.283837   247.978230    13.154199  414.796232
# 2007        79.697460    83.476942  2393.367265   114.587985  396.998217
# 2008       962.312164   182.286250  2697.961375  1369.682490  325.678573
# 2009      9415.173860  1213.265328  2643.441423  1139.112330   65.824121
# 2010     11938.212000  1377.821400  2965.824340  1463.213573  713.635620
# 2011     14166.499800  1564.966945  3275.916840  1644.619672  839.927936
# 2012      1592.681900   174.468298  3158.586880  1734.936120  955.648466
# 2013     16881.256800   197.551233  3167.343560   185.793359  111.227396
# 2014     16737.898270    25.448414  3148.365130  1738.882200  127.474620
# 2015              NaN          NaN          NaN          NaN         NaN
#
# [16 rows x 141 columns]

# %%
fig, axes = plt.subplots(figsize=(15,10))

sns.heatmap(gdp_summary.T[["Angola","Afghanistan"]], ax=axes, annot=True, cmap="Greens")
plt.show()

# %%
from scipy.stats.mstats import winsorize

# %%
gdp_summary.loc["Bangladesh"]
# Out:
# Year
# 2000     45.633710
# 2001     42.598115
# 2002      4.613575
# 2003    432.738897
# 2004     46.757917
# 2005    484.155471
# 2006    494.514660
# 2007    541.651484
# 2008    615.777541
# 2009    681.125368
# 2010    757.671757
# 2011    835.789341
# 2012    856.342857
# 2013    951.889453
# 2014    184.565430
# 2015           NaN
# Name: Bangladesh, dtype: float64

# %%
winsorize(gdp_summary.loc["Bangladesh"], limits=(0.20,0.10))
# Out:
# masked_array(data=[ 46.7579167,  46.7579167,  46.7579167, 432.7388972,
#                     46.7579167, 484.155471 , 494.51466  , 541.651484 ,
#                    615.7775411, 681.125368 , 757.6717572, 835.789341 ,
#                    856.342857 , 951.8894535, 184.56543  , 951.8894535],
#              mask=False,
#        fill_value=1e+20)

# %%
fig, axes = plt.subplots(ncols=2)

axes1, axes2 = axes

axes1.bar(gdp_summary.columns,gdp_summary.loc["Afghanistan"])
ms = winsorize(gdp_summary.loc["Afghanistan"], limits=(0.15,0.15))

axes2.bar(gdp_summary.columns,ms)
# Out:
# <BarContainer object of 16 artists>
