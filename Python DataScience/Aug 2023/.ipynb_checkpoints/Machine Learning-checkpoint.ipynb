# %%
# processs
# Performance -> P
# Task -> T
# Exerance -> E

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
import seaborn as sns

# %% [markdown]
# ## Regression

# %%
Rainfall =  np.random.randint(60,200,200)
Rainfall.sort()
Rainfall[:10]
# Out:
# array([61, 61, 61, 61, 62, 63, 64, 65, 66, 66])

# %%
Umbrella_sold = np.linspace(10,1000, len(Rainfall),dtype=np.int32)

# %%
Umbrella_sold[:10]
# Out:
# array([10, 14, 19, 24, 29, 34, 39, 44, 49, 54])

# %% [markdown]
# **Adding Noise**

# %%
Rainfall_noise = np.random.randint(-10,10, len(Rainfall))
Umbrella_noise = np.random.randint(-50,50, len(Rainfall))

# %%
rain =  pd.DataFrame({
    "RainFall": Rainfall+Rainfall_noise,
    "Umbrella Sold": np.abs(Umbrella_sold + Umbrella_noise)
})
rain.head()
# Out:
#    RainFall  Umbrella Sold
# 0        60             25
# 1        59             39
# 2        70             18
# 3        58              0
# 4        62             24

# %% [markdown]
# **Adding more point**

# %%
Rainfall_b =  np.random.randint(140,200,200)
Rainfall_b.sort()
Umbrella_sold_b = np.linspace(600,1000, len(Rainfall_b),dtype=np.int32)

Rainfall_noise_b = np.random.randint(-20,70, len(Rainfall_b))
Umbrella_noise_b = np.random.randint(-50,150, len(Rainfall_b))


Rainfall = np.concatenate((Rainfall, Rainfall_b))
Umbrella_sold = np.concatenate((Umbrella_sold, Umbrella_sold_b))

Rainfall_noise = np.concatenate((Rainfall_noise, Rainfall_noise_b))
Umbrella_noise = np.concatenate((Umbrella_noise, Umbrella_noise_b))

rain =  pd.DataFrame({
    "RainFall": Rainfall+Rainfall_noise,
    "Umbrella Sold": np.abs(Umbrella_sold + Umbrella_noise)
})
rain.head()
# Out:
#    RainFall  Umbrella Sold
# 0        60             25
# 1        59             39
# 2        70             18
# 3        58              0
# 4        62             24

# %%
plt.scatter(rain.RainFall,rain["Umbrella Sold"])
plt.xlabel("Rainfall (mm)")
plt.ylabel("Umberlla Sold")
plt.show()

# %%
a = np.array([1,2,3])
b = np.array([1,2,3])

# %%
np.concatenate((a,b))
# Out:
# array([1, 2, 3, 1, 2, 3])

# %%
rain["Umbrella Sold"].hist(bins=30)
# Out:
# <Axes: >

# %%
rain["RainFall"].hist(bins=30)
# Out:
# <Axes: >

# %%
rain["RainFall"].std()
# Out:
# 42.94946335330896

# %%
rain['Umbrella Sold'].std()
# Out:
# 248.94831009479455

# %%
reg =  LinearRegression()

# %%
train, test = train_test_split(rain, test_size=0.2)

# %%
reg.fit(Rainfall.reshape(-1,1), Umbrella_sold.reshape(-1,1))
# Out:
# LinearRegression()

# %%
reg.coef_
# Out:
# array([[7.40580486]])

# %%
Rainfall.reshape(-1,1).shape
# Out:
# (600, 1)

# %%
y_pred =  reg.predict(Rainfall.reshape(-1,1))

# %%
y_pred.shape
# Out:
# (600, 1)

# %%
predicted_rain =  pd.DataFrame({
    "RainFall": Rainfall,
    "Umbrella Sold": y_pred.flatten()
})

# %%
predicted_rain.sort_values("RainFall", inplace=True)

# %%
plt.scatter(rain.RainFall,rain["Umbrella Sold"])

plt.plot(rain.RainFall, y_pred, color='red')
plt.xlabel("Rainfall (mm)")
plt.ylabel("Umberlla Sold")
plt.show()

# %%
predicted_rain.sample(30)
# Out:
#      RainFall  Umbrella Sold
# 531       178     849.732112
# 525       175     827.514698
# 58        110     346.137382
# 345       184     894.166941
# 235       151     649.775381
# 367       191     946.007575
# 559       186     908.978551
# 369       191     946.007575
# 495       167     768.268259
# 254       158     701.616015
# 47        104     301.702552
# 356       188     923.790161
# 39         94     227.644504
# 305       173     812.703088
# 368       191     946.007575
# 136       159     709.021820
# 357       188     923.790161
# 594       198     997.848209
# 23         77     101.745821
# 350       186     908.978551
# 84        124     449.818650
# 288       169     783.079868
# 571       191     946.007575
# 523       174     820.108893
# 476       160     716.427625
# 225       148     627.557966
# 326       180     864.543722
# 226       148     627.557966
# 505       169     783.079868
# 550       183     886.761137

# %%
sns.lmplot(rain, x='RainFall', y="Umbrella Sold", line_kws={"color":'red'})
# Out:
# C:\Users\manis\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
