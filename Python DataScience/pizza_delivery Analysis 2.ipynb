# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
print("Hello")
# Out:
# Hello

# %%
df = pd.read_csv("./datasets/pizza_delivery.csv")

# %%
df.head()
# Out:
#         day       date       time operator branch     driver  temperature  \
# 0  Thursday  01-May-14  35.128367    Laura   East      Bruno    68.287716
# 1  Thursday  01-May-14  25.203074  Melissa   East  Salvatore    70.997791
# 2  Thursday  01-May-14  45.643404  Melissa   West  Salvatore    53.394145
# 3  Thursday  01-May-14  29.374298  Melissa   East  Salvatore    70.306596
# 4  Thursday  01-May-14  29.994610  Melissa   West  Salvatore    71.501688
#
#    bill  pizzas  free_wine  got_wine  discount_customer
# 0  58.4       4          0         0                  1
# 1  26.4       2          0         0                  0
# 2  58.1       3          1         0                  0
# 3  35.2       3          0         0                  0
# 4  38.4       2          0         0                  0

# %%
driver_group = df.groupby("driver")
# total amount of billing generated by each driver.
driver_bill = driver_group.bill.sum()
driver_bill
# Out:
# driver
# Bruno        14684.7
# Domenico      3095.8
# Luigi         5831.0
# Mario        15364.6
# Salvatore    15152.9
# Name: bill, dtype: float64

# %%
filtered_data =  df[df["temperature"] >70 ]
filtered_data
# Out:
#            day       date       time operator  branch     driver  temperature  \
# 1     Thursday  01-May-14  25.203074  Melissa    East  Salvatore    70.997791
# 3     Thursday  01-May-14  29.374298  Melissa    East  Salvatore    70.306596
# 4     Thursday  01-May-14  29.994610  Melissa    West  Salvatore    71.501688
# 13    Thursday  01-May-14  25.451977  Melissa  Centre  Salvatore    74.861414
# 15    Thursday  01-May-14  40.719208  Melissa    West  Salvatore    71.216953
# ...        ...        ...        ...      ...     ...        ...          ...
# 1222  Saturday  31-May-14  23.767364  Melissa    West   Domenico    73.494703
# 1223  Saturday  31-May-14  25.700244    Laura    East   Domenico    73.283141
# 1225  Saturday  31-May-14  32.656533    Laura    East      Mario    70.213120
# 1236  Saturday  31-May-14  34.892592    Laura    West      Mario    70.723756
# 1243  Saturday  31-May-14  21.314470    Laura    East   Domenico    74.902024
#
# ...

# %%
driver_group = filtered_data.groupby("driver")
filtered_data_bill =  driver_group.bill.sum()
filtered_data_bill
# Out:
# driver
# Bruno         912.1
# Domenico     1382.2
# Luigi         925.4
# Mario        1176.5
# Salvatore    1500.7
# Name: bill, dtype: float64

# %%
# first of all we need to plot the figure and an axes.
fig, axes = plt.subplots(figsize = (6, 4))

# ploting the bar graph of the summary.
axes.pie(driver_bill, labels=driver_bill.index, autopct="%0.2f%%")
# setting the x and y label
axes.set_xlabel("Branch")
axes.set_ylabel("Total Billing Amount")

# Now we will set the title for our graph.
plt.title("Total Revenue Generated by Each Driver")
plt.show()

# %%
pd.DataFrame({"filter":filtered_data_bill, "all":driver_bill, "diff": driver_bill-filtered_data_bill})
# Out:
#            filter      all     diff
# driver
# Bruno       912.1  14684.7  13772.6
# Domenico   1382.2   3095.8   1713.6
# Luigi       925.4   5831.0   4905.6
# Mario      1176.5  15364.6  14188.1
# Salvatore  1500.7  15152.9  13652.2

# %%
df[df.driver=="Bruno"].hist("temperature", bins=20)
# Out:
# array([[<Axes: title={'center': 'temperature'}>]], dtype=object)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1266 entries, 0 to 1265
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   day                1266 non-null   object
#  1   date               1266 non-null   object
#  2   time               1266 non-null   float64
#  3   operator           1266 non-null   object
#  4   branch             1266 non-null   object
#  5   driver             1266 non-null   object
#  6   temperature        1266 non-null   float64
#  7   bill               1266 non-null   float64
#  8   pizzas             1266 non-null   int64
#  9   free_wine          1266 non-null   int64
#  10  got_wine           1266 non-null   int64
#  11  discount_customer  1266 non-null   int64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 118.8+ KB

# %%
df = pd.read_csv("./datasets/Life Expectancy Data.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [2], line 1
# ----> 1 df = pd.read_csv("./datasets/Life Expectancy Data.csv")
#
# NameError: name 'pd' is not defined

# %%
df.isnull()
# Out:
#       Country   Year  Status  Life expectancy   Adult Mortality  \
# 0       False  False   False             False            False
# 1       False  False   False             False            False
# 2       False  False   False             False            False
# 3       False  False   False             False            False
# 4       False  False   False             False            False
# ...       ...    ...     ...               ...              ...
# 2933    False  False   False             False            False
# 2934    False  False   False             False            False
# 2935    False  False   False             False            False
# 2936    False  False   False             False            False
# 2937    False  False   False             False            False
#
#       infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   \
# 0             False    False                   False        False     False
# ...

# %%
df.isnull().sum()
# Out:
# Country                              0
# Year                                 0
# Status                               0
# Life expectancy                     10
# Adult Mortality                     10
# infant deaths                        0
# Alcohol                            194
# percentage expenditure               0
# Hepatitis B                        553
# Measles                              0
#  BMI                                34
# under-five deaths                    0
# Polio                               19
# Total expenditure                  226
# Diphtheria                          19
#  HIV/AIDS                            0
# GDP                                448
# Population                         652
#  thinness  1-19 years               34
#  thinness 5-9 years                 34
# Income composition of resources    167
# Schooling                          163
# dtype: int64

# %%
df.isna().sum()
# Out:
# Country                              0
# Year                                 0
# Status                               0
# Life expectancy                     10
# Adult Mortality                     10
# infant deaths                        0
# Alcohol                            194
# percentage expenditure               0
# Hepatitis B                        553
# Measles                              0
#  BMI                                34
# under-five deaths                    0
# Polio                               19
# Total expenditure                  226
# Diphtheria                          19
#  HIV/AIDS                            0
# GDP                                448
# Population                         652
#  thinness  1-19 years               34
#  thinness 5-9 years                 34
# Income composition of resources    167
# Schooling                          163
# dtype: int64

# %%
df.tail()
# Out:
#        Country  Year      Status  Life expectancy   Adult Mortality  \
# 2933  Zimbabwe  2004  Developing              44.3            723.0
# 2934  Zimbabwe  2003  Developing              44.5            715.0
# 2935  Zimbabwe  2002  Developing              44.8             73.0
# 2936  Zimbabwe  2001  Developing              45.3            686.0
# 2937  Zimbabwe  2000  Developing              46.0            665.0
#
#       infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   \
# 2933             27     4.36                     0.0         68.0        31
# 2934             26     4.06                     0.0          7.0       998
# 2935             25     4.43                     0.0         73.0       304
# 2936             25     1.72                     0.0         76.0       529
# 2937             24     1.68                     0.0         79.0      1483
#
#       ...  Polio  Total expenditure  Diphtheria    HIV/AIDS         GDP  \
# ...

# %%
df.columns
# Out:
# Index(['Country', 'Year', 'Status', 'Life expectancy ', 'Adult Mortality',
#        'infant deaths', 'Alcohol', 'percentage expenditure', 'Hepatitis B',
#        'Measles ', ' BMI ', 'under-five deaths ', 'Polio', 'Total expenditure',
#        'Diphtheria ', ' HIV/AIDS', 'GDP', 'Population',
#        ' thinness  1-19 years', ' thinness 5-9 years',
#        'Income composition of resources', 'Schooling'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=2938, step=1)

# %%
df.set_index("Country", inplace=True)

# %%
df
# Out:
#              Year      Status  Life expectancy   Adult Mortality  \
# Country
# Afghanistan  2015  Developing              65.0            263.0
# Afghanistan  2014  Developing              59.9            271.0
# Afghanistan  2013  Developing              59.9            268.0
# Afghanistan  2012  Developing              59.5            272.0
# Afghanistan  2011  Developing              59.2            275.0
# ...           ...         ...               ...              ...
# Zimbabwe     2004  Developing              44.3            723.0
# Zimbabwe     2003  Developing              44.5            715.0
# Zimbabwe     2002  Developing              44.8             73.0
# Zimbabwe     2001  Developing              45.3            686.0
# Zimbabwe     2000  Developing              46.0            665.0
#
#              infant deaths  Alcohol  percentage expenditure  Hepatitis B  \
# Country
# Afghanistan             62     0.01               71.279624         65.0
# ...

# %%
df.index.unique().size
# Out:
# 193

# %%
df.dtypes
# Out:
# Year                                 int64
# Status                              object
# Life expectancy                    float64
# Adult Mortality                    float64
# infant deaths                        int64
# Alcohol                            float64
# percentage expenditure             float64
# Hepatitis B                        float64
# Measles                              int64
#  BMI                               float64
# under-five deaths                    int64
# Polio                              float64
# Total expenditure                  float64
# Diphtheria                         float64
#  HIV/AIDS                          float64
# GDP                                float64
# Population                         float64
#  thinness  1-19 years              float64
#  thinness 5-9 years                float64
# Income composition of resources    float64
# Schooling                          float64
# dtype: object

# %%
df2= df.convert_dtypes()

# %%
df2.dtypes
# Out:
# Year                                        Int64
# Status                             string[python]
# Life expectancy                           Float64
# Adult Mortality                             Int64
# infant deaths                               Int64
# Alcohol                                   Float64
# percentage expenditure                    Float64
# Hepatitis B                                 Int64
# Measles                                     Int64
#  BMI                                      Float64
# under-five deaths                           Int64
# Polio                                       Int64
# Total expenditure                         Float64
# Diphtheria                                  Int64
#  HIV/AIDS                                 Float64
# GDP                                       Float64
# Population                                Float64
#  thinness  1-19 years                     Float64
#  thinness 5-9 years                       Float64
# ...

# %%
df.shape
# Out:
# (2938, 21)

# %%
df.ndim
# Out:
# 2

# %%
df.columns = [col.strip() for col in df.columns]

# %% [markdown]
# ## Accessing data only for a single group by using only index

# %%
group = df.groupby("Country")

# %%
group.get_group("Albania")
# if we don't have the key inside the index then keyError will be raised.
# Out:
#          Year      Status  Life expectancy  Adult Mortality  infant deaths  \
# Country
# Albania  2015  Developing             77.8             74.0              0
# Albania  2014  Developing             77.5              8.0              0
# Albania  2013  Developing             77.2             84.0              0
# Albania  2012  Developing             76.9             86.0              0
# Albania  2011  Developing             76.6             88.0              0
# Albania  2010  Developing             76.2             91.0              1
# Albania  2009  Developing             76.1             91.0              1
# Albania  2008  Developing             75.3              1.0              1
# Albania  2007  Developing             75.9              9.0              1
# Albania  2006  Developing             74.2             99.0              1
# Albania  2005  Developing             73.5             15.0              1
# ...

# %%
df["Life expectancy"]
# Out:
# Country
# Afghanistan    65.0
# Afghanistan    59.9
# Afghanistan    59.9
# Afghanistan    59.5
# Afghanistan    59.2
#                ...
# Zimbabwe       44.3
# Zimbabwe       44.5
# Zimbabwe       44.8
# Zimbabwe       45.3
# Zimbabwe       46.0
# Name: Life expectancy, Length: 2938, dtype: float64

# %%
lfs =  (df["Life expectancy"]>55)
lfs_in = ~lfs

# %%
lfs.sum()

# %%
lfs_in.sum()

# %%
df[lfs_in]

# %%
df.describe()

# %%
df.isna().sum()

# %%
life_expectancy =  df["Life expectancy"]
life_expectancy
# Out:
# Country
# Afghanistan    65.0
# Afghanistan    59.9
# Afghanistan    59.9
# Afghanistan    59.5
# Afghanistan    59.2
#                ...
# Zimbabwe       44.3
# Zimbabwe       44.5
# Zimbabwe       44.8
# Zimbabwe       45.3
# Zimbabwe       46.0
# Name: Life expectancy, Length: 2938, dtype: float64

# %%
life_expectancy.index
# Out:
# Index(['Afghanistan', 'Afghanistan', 'Afghanistan', 'Afghanistan',
#        'Afghanistan', 'Afghanistan', 'Afghanistan', 'Afghanistan',
#        'Afghanistan', 'Afghanistan',
#        ...
#        'Zimbabwe', 'Zimbabwe', 'Zimbabwe', 'Zimbabwe', 'Zimbabwe', 'Zimbabwe',
#        'Zimbabwe', 'Zimbabwe', 'Zimbabwe', 'Zimbabwe'],
#       dtype='object', name='Country', length=2938)

# %%
life_expectancy.values
# Out:
# array([65. , 59.9, 59.9, ..., 44.8, 45.3, 46. ])

# %%
life_expectancy.to_numpy()
# Out:
# array([65. , 59.9, 59.9, ..., 44.8, 45.3, 46. ])

# %%
life_expectancy.to_numpy()
# Out:
# array([65. , 59.9, 59.9, ..., 44.8, 45.3, 46. ])

# %%
life_expectancy.dtype
# Out:
# dtype('float64')

# %%
life_expectancy.shape
# Out:
# (2938,)

# %%
life_expectancy.ndim
# Out:
# 1

# %%
life_expectancy.size
# Out:
# 2938

# %%
# df.T transpose
df.describe().T
# Out:
#                                   count          mean           std  \
# Year                             2938.0  2.007519e+03  4.613841e+00
# Life expectancy                  2928.0  6.922493e+01  9.523867e+00
# Adult Mortality                  2928.0  1.647964e+02  1.242921e+02
# infant deaths                    2938.0  3.030395e+01  1.179265e+02
# Alcohol                          2744.0  4.602861e+00  4.052413e+00
# percentage expenditure           2938.0  7.382513e+02  1.987915e+03
# Hepatitis B                      2385.0  8.094046e+01  2.507002e+01
# Measles                          2938.0  2.419592e+03  1.146727e+04
# BMI                              2904.0  3.832125e+01  2.004403e+01
# under-five deaths                2938.0  4.203574e+01  1.604455e+02
# Polio                            2919.0  8.255019e+01  2.342805e+01
# Total expenditure                2712.0  5.938190e+00  2.498320e+00
# Diphtheria                       2919.0  8.232408e+01  2.371691e+01
# ...

# %%
life_expectancy.name
# Out:
# 'Life expectancy'

# %%
life_expectancy
# Out:
# Country
# Afghanistan    65.0
# Afghanistan    59.9
# Afghanistan    59.9
# Afghanistan    59.5
# Afghanistan    59.2
#                ...
# Zimbabwe       44.3
# Zimbabwe       44.5
# Zimbabwe       44.8
# Zimbabwe       45.3
# Zimbabwe       46.0
# Name: Life expectancy, Length: 2938, dtype: float64

# %%
life_expectancy.rename({"Afghanistan":"Afgan"})
# Out:
# Country
# Afgan       65.0
# Afgan       59.9
# Afgan       59.9
# Afgan       59.5
# Afgan       59.2
#             ...
# Zimbabwe    44.3
# Zimbabwe    44.5
# Zimbabwe    44.8
# Zimbabwe    45.3
# Zimbabwe    46.0
# Name: Life expectancy, Length: 2938, dtype: float64

# %%
life_expectancy.memory_usage()/1024
# Out:
# 110.4453125

# %%
life_expectancy.dropna()
# Out:
# Country
# Afghanistan    65.0
# Afghanistan    59.9
# Afghanistan    59.9
# Afghanistan    59.5
# Afghanistan    59.2
#                ...
# Zimbabwe       44.3
# Zimbabwe       44.5
# Zimbabwe       44.8
# Zimbabwe       45.3
# Zimbabwe       46.0
# Name: Life expectancy, Length: 2928, dtype: float64

# %%
life_expectancy.dropna().astype(np.int8).memory_usage()/1024
# Out:
# 25.734375

# %%
life_expectancy.size
# Out:
# 2938

# %%
life_expectancy.dropna().size
# Out:
# 2928

# %%
life_expectancy.dropna().astype(np.int8)
# Out:
# Country
# Afghanistan    65
# Afghanistan    59
# Afghanistan    59
# Afghanistan    59
# Afghanistan    59
#                ..
# Zimbabwe       44
# Zimbabwe       44
# Zimbabwe       44
# Zimbabwe       45
# Zimbabwe       46
# Name: Life expectancy, Length: 2928, dtype: int8

# %%
a = (life_expectancy<40)

# %%
df.iat[0,0]
# Out:
# 2015

# %%
df.at["Zimbabwe","Life expectancy"]
# Out:
# Country
# Zimbabwe    67.0
# Zimbabwe    59.2
# Zimbabwe    58.0
# Zimbabwe    56.6
# Zimbabwe    54.9
# Zimbabwe    52.4
# Zimbabwe    50.0
# Zimbabwe    48.2
# Zimbabwe    46.6
# Zimbabwe    45.4
# Zimbabwe    44.6
# Zimbabwe    44.3
# Zimbabwe    44.5
# Zimbabwe    44.8
# Zimbabwe    45.3
# Zimbabwe    46.0
# Name: Life expectancy, dtype: float64

# %%
df.loc["Zimbabwe"]

# %%
df["Status"]
# Out:
# Country
# Afghanistan    Developing
# Afghanistan    Developing
# Afghanistan    Developing
# Afghanistan    Developing
# Afghanistan    Developing
#                   ...
# Zimbabwe       Developing
# Zimbabwe       Developing
# Zimbabwe       Developing
# Zimbabwe       Developing
# Zimbabwe       Developing
# Name: Status, Length: 2938, dtype: object

# %%
items =  df["Status"].items()

# %%
next(items)

# %%
df["Status"][0]

# %%
df["Status"]

# %% [markdown]
# ### Filtering

# %% [markdown]
# #### select only few coloumns

# %%
df.reset_index(inplace=True)
df.head()
# Out:
#        Country  Year      Status  Life expectancy  Adult Mortality  \
# 0  Afghanistan  2015  Developing             65.0            263.0
# 1  Afghanistan  2014  Developing             59.9            271.0
# 2  Afghanistan  2013  Developing             59.9            268.0
# 3  Afghanistan  2012  Developing             59.5            272.0
# 4  Afghanistan  2011  Developing             59.2            275.0
#
#    infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles  ...  \
# 0             62     0.01               71.279624         65.0     1154  ...
# 1             64     0.01               73.523582         62.0      492  ...
# 2             66     0.01               73.219243         64.0      430  ...
# 3             69     0.01               78.184215         67.0     2787  ...
# 4             71     0.01                7.097109         68.0     3013  ...
#
#    Polio  Total expenditure  Diphtheria  HIV/AIDS         GDP  Population  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2938 entries, 0 to 2937
# Data columns (total 22 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Country                          2938 non-null   object
#  1   Year                             2938 non-null   int64
#  2   Status                           2938 non-null   object
#  3   Life expectancy                  2928 non-null   float64
#  4   Adult Mortality                  2928 non-null   float64
#  5   infant deaths                    2938 non-null   int64
#  6   Alcohol                          2744 non-null   float64
#  7   percentage expenditure           2938 non-null   float64
#  8   Hepatitis B                      2385 non-null   float64
#  9   Measles                          2938 non-null   int64
#  10  BMI                              2904 non-null   float64
#  11  under-five deaths                2938 non-null   int64
# ...

# %%
df.rename(columns={col:col.strip() for col in df.columns}, inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2938 entries, 0 to 2937
# Data columns (total 22 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Country                          2938 non-null   object
#  1   Year                             2938 non-null   int64
#  2   Status                           2938 non-null   object
#  3   Life expectancy                  2928 non-null   float64
#  4   Adult Mortality                  2928 non-null   float64
#  5   infant deaths                    2938 non-null   int64
#  6   Alcohol                          2744 non-null   float64
#  7   percentage expenditure           2938 non-null   float64
#  8   Hepatitis B                      2385 non-null   float64
#  9   Measles                          2938 non-null   int64
#  10  BMI                              2904 non-null   float64
#  11  under-five deaths                2938 non-null   int64
# ...

# %%
df1 =  df[["Country", "Year","Status","Life expectancy", "Alcohol","Schooling"]]

# %%
df1.head()
# Out:
#        Country  Year      Status  Life expectancy  Alcohol  Schooling
# 0  Afghanistan  2015  Developing             65.0     0.01       10.1
# 1  Afghanistan  2014  Developing             59.9     0.01       10.0
# 2  Afghanistan  2013  Developing             59.9     0.01        9.9
# 3  Afghanistan  2012  Developing             59.5     0.01        9.8
# 4  Afghanistan  2011  Developing             59.2     0.01        9.5

# %%
df["Status"] == "Developing"
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#         ...
# 2933    True
# 2934    True
# 2935    True
# 2936    True
# 2937    True
# Name: Status, Length: 2938, dtype: bool

# %%
(df["Status"] == "Developing").sum()
# Out:
# 2426

# %%
df.shape
# Out:
# (2938, 22)

# %%
df1.drop(columns="Status", inplace=True)
# Out:
# C:\Users\manis\AppData\Local\Temp\ipykernel_18344\3740639791.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1.drop(columns="Status", inplace=True)

# %%
df1["Year"] == 2015
# Out:
# 0        True
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 2933    False
# 2934    False
# 2935    False
# 2936    False
# 2937    False
# Name: Year, Length: 2938, dtype: bool

# %%
df["Status"].unique()
# Out:
# array(['Developing', 'Developed'], dtype=object)

# %%
df.head()
# Out:
#        Country  Year      Status  Life expectancy  Adult Mortality  \
# 0  Afghanistan  2015  Developing             65.0            263.0
# 1  Afghanistan  2014  Developing             59.9            271.0
# 2  Afghanistan  2013  Developing             59.9            268.0
# 3  Afghanistan  2012  Developing             59.5            272.0
# 4  Afghanistan  2011  Developing             59.2            275.0
#
#    infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles  ...  \
# 0             62     0.01               71.279624         65.0     1154  ...
# 1             64     0.01               73.523582         62.0      492  ...
# 2             66     0.01               73.219243         64.0      430  ...
# 3             69     0.01               78.184215         67.0     2787  ...
# 4             71     0.01                7.097109         68.0     3013  ...
#
#    Polio  Total expenditure  Diphtheria  HIV/AIDS         GDP  Population  \
# ...
