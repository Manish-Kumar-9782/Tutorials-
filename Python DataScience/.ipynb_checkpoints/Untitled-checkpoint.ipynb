# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("./datasets/pizza_delivery.csv")

# %%
df.isnull()
# Out:
#         day   date   time  operator  branch  driver  temperature   bill  \
# 0     False  False  False     False   False   False        False  False
# 1     False  False  False     False   False   False        False  False
# 2     False  False  False     False   False   False        False  False
# 3     False  False  False     False   False   False        False  False
# 4     False  False  False     False   False   False        False  False
# ...     ...    ...    ...       ...     ...     ...          ...    ...
# 1261  False  False  False     False   False   False        False  False
# 1262  False  False  False     False   False   False        False  False
# 1263  False  False  False     False   False   False        False  False
# 1264  False  False  False     False   False   False        False  False
# 1265  False  False  False     False   False   False        False  False
#
#       pizzas  free_wine  got_wine  discount_customer
# 0      False      False     False              False
# 1      False      False     False              False
# 2      False      False     False              False
# 3      False      False     False              False
# 4      False      False     False              False
# ...      ...        ...       ...                ...
# 1261   False      False     False              False
# 1262   False      False     False              False
# 1263   False      False     False              False
# 1264   False      False     False              False
# 1265   False      False     False              False
#
# [1266 rows x 12 columns]

# %%
df.isnull().sum()
# Out:
# day                  0
# date                 0
# time                 0
# operator             0
# branch               0
# driver               0
# temperature          0
# bill                 0
# pizzas               0
# free_wine            0
# got_wine             0
# discount_customer    0
# dtype: int64

# %%
df = pd.read_csv("./datasets/Life Expectancy Data.csv")

# %%
df.isnull()
# Out:
#       Country   Year  Status  Life expectancy   Adult Mortality  \
# 0       False  False   False             False            False
# 1       False  False   False             False            False
# 2       False  False   False             False            False
# 3       False  False   False             False            False
# 4       False  False   False             False            False
# ...       ...    ...     ...               ...              ...
# 2933    False  False   False             False            False
# 2934    False  False   False             False            False
# 2935    False  False   False             False            False
# 2936    False  False   False             False            False
# 2937    False  False   False             False            False
#
#       infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   \
# 0             False    False                   False        False     False
# 1             False    False                   False        False     False
# 2             False    False                   False        False     False
# 3             False    False                   False        False     False
# 4             False    False                   False        False     False
# ...             ...      ...                     ...          ...       ...
# 2933          False    False                   False        False     False
# 2934          False    False                   False        False     False
# 2935          False    False                   False        False     False
# 2936          False    False                   False        False     False
# 2937          False    False                   False        False     False
#
#       ...  Polio  Total expenditure  Diphtheria    HIV/AIDS    GDP  \
# 0     ...  False              False        False      False  False
# 1     ...  False              False        False      False  False
# 2     ...  False              False        False      False  False
# 3     ...  False              False        False      False  False
# 4     ...  False              False        False      False  False
# ...   ...    ...                ...          ...        ...    ...
# 2933  ...  False              False        False      False  False
# 2934  ...  False              False        False      False  False
# 2935  ...  False              False        False      False  False
# 2936  ...  False              False        False      False  False
# 2937  ...  False              False        False      False  False
#
#       Population   thinness  1-19 years   thinness 5-9 years  \
# 0          False                  False                False
# 1          False                  False                False
# 2          False                  False                False
# 3          False                  False                False
# 4          False                  False                False
# ...          ...                    ...                  ...
# 2933       False                  False                False
# 2934       False                  False                False
# 2935       False                  False                False
# 2936       False                  False                False
# 2937       False                  False                False
#
#       Income composition of resources  Schooling
# 0                               False      False
# 1                               False      False
# 2                               False      False
# 3                               False      False
# 4                               False      False
# ...                               ...        ...
# 2933                            False      False
# 2934                            False      False
# 2935                            False      False
# 2936                            False      False
# 2937                            False      False
#
# [2938 rows x 22 columns]

# %%
df.isnull().sum()
# Out:
# Country                              0
# Year                                 0
# Status                               0
# Life expectancy                     10
# Adult Mortality                     10
# infant deaths                        0
# Alcohol                            194
# percentage expenditure               0
# Hepatitis B                        553
# Measles                              0
#  BMI                                34
# under-five deaths                    0
# Polio                               19
# Total expenditure                  226
# Diphtheria                          19
#  HIV/AIDS                            0
# GDP                                448
# Population                         652
#  thinness  1-19 years               34
#  thinness 5-9 years                 34
# Income composition of resources    167
# Schooling                          163
# dtype: int64

# %%
df.isna().sum()
# Out:
# Country                              0
# Year                                 0
# Status                               0
# Life expectancy                     10
# Adult Mortality                     10
# infant deaths                        0
# Alcohol                            194
# percentage expenditure               0
# Hepatitis B                        553
# Measles                              0
#  BMI                                34
# under-five deaths                    0
# Polio                               19
# Total expenditure                  226
# Diphtheria                          19
#  HIV/AIDS                            0
# GDP                                448
# Population                         652
#  thinness  1-19 years               34
#  thinness 5-9 years                 34
# Income composition of resources    167
# Schooling                          163
# dtype: int64

# %%
df.tail()
# Out:
#        Country  Year      Status  Life expectancy   Adult Mortality  \
# 2933  Zimbabwe  2004  Developing              44.3            723.0
# 2934  Zimbabwe  2003  Developing              44.5            715.0
# 2935  Zimbabwe  2002  Developing              44.8             73.0
# 2936  Zimbabwe  2001  Developing              45.3            686.0
# 2937  Zimbabwe  2000  Developing              46.0            665.0
#
#       infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   \
# 2933             27     4.36                     0.0         68.0        31
# 2934             26     4.06                     0.0          7.0       998
# 2935             25     4.43                     0.0         73.0       304
# 2936             25     1.72                     0.0         76.0       529
# 2937             24     1.68                     0.0         79.0      1483
#
#       ...  Polio  Total expenditure  Diphtheria    HIV/AIDS         GDP  \
# 2933  ...   67.0               7.13         65.0       33.6  454.366654
# 2934  ...    7.0               6.52         68.0       36.7  453.351155
# 2935  ...   73.0               6.53         71.0       39.8   57.348340
# 2936  ...   76.0               6.16         75.0       42.1  548.587312
# 2937  ...   78.0               7.10         78.0       43.5  547.358878
#
#       Population   thinness  1-19 years   thinness 5-9 years  \
# 2933  12777511.0                    9.4                  9.4
# 2934  12633897.0                    9.8                  9.9
# 2935    125525.0                    1.2                  1.3
# 2936  12366165.0                    1.6                  1.7
# 2937  12222251.0                   11.0                 11.2
#
#       Income composition of resources  Schooling
# 2933                            0.407        9.2
# 2934                            0.418        9.5
# 2935                            0.427       10.0
# 2936                            0.427        9.8
# 2937                            0.434        9.8
#
# [5 rows x 22 columns]

# %%
df.columns
# Out:
# Index(['Country', 'Year', 'Status', 'Life expectancy ', 'Adult Mortality',
#        'infant deaths', 'Alcohol', 'percentage expenditure', 'Hepatitis B',
#        'Measles ', ' BMI ', 'under-five deaths ', 'Polio', 'Total expenditure',
#        'Diphtheria ', ' HIV/AIDS', 'GDP', 'Population',
#        ' thinness  1-19 years', ' thinness 5-9 years',
#        'Income composition of resources', 'Schooling'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=2938, step=1)

# %%
df.set_index("Country", inplace=True)

# %%
df
# Out:
#              Year      Status  Life expectancy   Adult Mortality  \
# Country
# Afghanistan  2015  Developing              65.0            263.0
# Afghanistan  2014  Developing              59.9            271.0
# Afghanistan  2013  Developing              59.9            268.0
# Afghanistan  2012  Developing              59.5            272.0
# Afghanistan  2011  Developing              59.2            275.0
# ...           ...         ...               ...              ...
# Zimbabwe     2004  Developing              44.3            723.0
# Zimbabwe     2003  Developing              44.5            715.0
# Zimbabwe     2002  Developing              44.8             73.0
# Zimbabwe     2001  Developing              45.3            686.0
# Zimbabwe     2000  Developing              46.0            665.0
#
#              infant deaths  Alcohol  percentage expenditure  Hepatitis B  \
# Country
# Afghanistan             62     0.01               71.279624         65.0
# Afghanistan             64     0.01               73.523582         62.0
# Afghanistan             66     0.01               73.219243         64.0
# Afghanistan             69     0.01               78.184215         67.0
# Afghanistan             71     0.01                7.097109         68.0
# ...                    ...      ...                     ...          ...
# Zimbabwe                27     4.36                0.000000         68.0
# Zimbabwe                26     4.06                0.000000          7.0
# Zimbabwe                25     4.43                0.000000         73.0
# Zimbabwe                25     1.72                0.000000         76.0
# Zimbabwe                24     1.68                0.000000         79.0
#
#              Measles    BMI   ...  Polio  Total expenditure  Diphtheria   \
# Country                       ...
# Afghanistan      1154   19.1  ...    6.0               8.16         65.0
# Afghanistan       492   18.6  ...   58.0               8.18         62.0
# Afghanistan       430   18.1  ...   62.0               8.13         64.0
# Afghanistan      2787   17.6  ...   67.0               8.52         67.0
# Afghanistan      3013   17.2  ...   68.0               7.87         68.0
# ...               ...    ...  ...    ...                ...          ...
# Zimbabwe           31   27.1  ...   67.0               7.13         65.0
# Zimbabwe          998   26.7  ...    7.0               6.52         68.0
# Zimbabwe          304   26.3  ...   73.0               6.53         71.0
# Zimbabwe          529   25.9  ...   76.0               6.16         75.0
# Zimbabwe         1483   25.5  ...   78.0               7.10         78.0
#
#               HIV/AIDS         GDP  Population   thinness  1-19 years  \
# Country
# Afghanistan        0.1  584.259210  33736494.0                   17.2
# Afghanistan        0.1  612.696514    327582.0                   17.5
# Afghanistan        0.1  631.744976  31731688.0                   17.7
# Afghanistan        0.1  669.959000   3696958.0                   17.9
# Afghanistan        0.1   63.537231   2978599.0                   18.2
# ...                ...         ...         ...                    ...
# Zimbabwe          33.6  454.366654  12777511.0                    9.4
# Zimbabwe          36.7  453.351155  12633897.0                    9.8
# Zimbabwe          39.8   57.348340    125525.0                    1.2
# Zimbabwe          42.1  548.587312  12366165.0                    1.6
# Zimbabwe          43.5  547.358878  12222251.0                   11.0
#
#               thinness 5-9 years  Income composition of resources  Schooling
# Country
# Afghanistan                 17.3                            0.479       10.1
# Afghanistan                 17.5                            0.476       10.0
# Afghanistan                 17.7                            0.470        9.9
# Afghanistan                 18.0                            0.463        9.8
# Afghanistan                 18.2                            0.454        9.5
# ...                          ...                              ...        ...
# Zimbabwe                     9.4                            0.407        9.2
# Zimbabwe                     9.9                            0.418        9.5
# Zimbabwe                     1.3                            0.427       10.0
# Zimbabwe                     1.7                            0.427        9.8
# Zimbabwe                    11.2                            0.434        9.8
#
# [2938 rows x 21 columns]

# %%
df.index.unique().size
# Out:
# 193

# %%
df.dtypes
# Out:
# Year                                 int64
# Status                              object
# Life expectancy                    float64
# Adult Mortality                    float64
# infant deaths                        int64
# Alcohol                            float64
# percentage expenditure             float64
# Hepatitis B                        float64
# Measles                              int64
#  BMI                               float64
# under-five deaths                    int64
# Polio                              float64
# Total expenditure                  float64
# Diphtheria                         float64
#  HIV/AIDS                          float64
# GDP                                float64
# Population                         float64
#  thinness  1-19 years              float64
#  thinness 5-9 years                float64
# Income composition of resources    float64
# Schooling                          float64
# dtype: object

# %%
df2= df.convert_dtypes()

# %%
df2.dtypes
# Out:
# Year                                        Int64
# Status                             string[python]
# Life expectancy                           Float64
# Adult Mortality                             Int64
# infant deaths                               Int64
# Alcohol                                   Float64
# percentage expenditure                    Float64
# Hepatitis B                                 Int64
# Measles                                     Int64
#  BMI                                      Float64
# under-five deaths                           Int64
# Polio                                       Int64
# Total expenditure                         Float64
# Diphtheria                                  Int64
#  HIV/AIDS                                 Float64
# GDP                                       Float64
# Population                                Float64
#  thinness  1-19 years                     Float64
#  thinness 5-9 years                       Float64
# Income composition of resources           Float64
# Schooling                                 Float64
# dtype: object

# %%
df.shape
# Out:
# (2938, 21)

# %%
df.ndim
# Out:
# 2

# %%
df.index.unique()
# Out:
# Index(['Afghanistan', 'Albania', 'Algeria', 'Angola', 'Antigua and Barbuda',
#        'Argentina', 'Armenia', 'Australia', 'Austria', 'Azerbaijan',
#        ...
#        'United Republic of Tanzania', 'United States of America', 'Uruguay',
#        'Uzbekistan', 'Vanuatu', 'Venezuela (Bolivarian Republic of)',
#        'Viet Nam', 'Yemen', 'Zambia', 'Zimbabwe'],
#       dtype='object', name='Country', length=193)

# %% [markdown]
# ## Accessing data only for a single group by using only index

# %%
def getbyCountry(dataframe,index):
    return dataframe.loc[index]

# %%
getbyCountry(df.reset_index(),"Albania")
# if we don't have the key inside the index then keyError will be raised.
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In [22], line 1
# ----> 1 getbyCountry(df.reset_index(),"Albania")
#
# Cell In [21], line 2, in getbyCountry(dataframe, index)
#       1 def getbyCountry(dataframe,index):
# ----> 2     return dataframe.loc[index]
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexing.py:1103, in _LocationIndexer.__getitem__(self, key)
#    1100 axis = self.axis or 0
#    1102 maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1103 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexing.py:1343, in _LocIndexer._getitem_axis(self, key, axis)
#    1341 # fall thru to straight lookup
#    1342 self._validate_key(key, axis)
# -> 1343 return self._get_label(key, axis=axis)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexing.py:1293, in _LocIndexer._get_label(self, label, axis)
#    1291 def _get_label(self, label, axis: AxisInt):
#    1292     # GH#5567 this will fail if the label is not present in the axis.
# -> 1293     return self.obj.xs(label, axis=axis)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\generic.py:4095, in NDFrame.xs(self, key, axis, level, drop_level)
#    4093             new_index = index[loc]
#    4094 else:
# -> 4095     loc = index.get_loc(key)
#    4097     if isinstance(loc, np.ndarray):
#    4098         if loc.dtype == np.bool_:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\range.py:349, in RangeIndex.get_loc(self, key)
#     347         raise KeyError(key) from err
#     348 if isinstance(key, Hashable):
# --> 349     raise KeyError(key)
#     350 self._check_indexing_error(key)
#     351 raise KeyError(key)
#
# KeyError: 'Albania'

# %%
df["Life expectancy "]
# Out:
# Country
# Afghanistan    65.0
# Afghanistan    59.9
# Afghanistan    59.9
# Afghanistan    59.5
# Afghanistan    59.2
#                ...
# Zimbabwe       44.3
# Zimbabwe       44.5
# Zimbabwe       44.8
# Zimbabwe       45.3
# Zimbabwe       46.0
# Name: Life expectancy , Length: 2938, dtype: float64

# %%
lfs =  (df["Life expectancy "]>55)
lfs_in = ~lfs

# %%
lfs.sum()
# Out:
# 2613

# %%
lfs_in.sum()
# Out:
# 325

# %%
df[lfs_in]
# Out:
#              Year      Status  Life expectancy   Adult Mortality  \
# Country
# Afghanistan  2000  Developing              54.8            321.0
# Angola       2015  Developing              52.4            335.0
# Angola       2014  Developing              51.7            348.0
# Angola       2013  Developing              51.1            355.0
# Angola       2011  Developing              51.0            361.0
# ...           ...         ...               ...              ...
# Zimbabwe     2004  Developing              44.3            723.0
# Zimbabwe     2003  Developing              44.5            715.0
# Zimbabwe     2002  Developing              44.8             73.0
# Zimbabwe     2001  Developing              45.3            686.0
# Zimbabwe     2000  Developing              46.0            665.0
#
#              infant deaths  Alcohol  percentage expenditure  Hepatitis B  \
# Country
# Afghanistan             88     0.01               10.424960         62.0
# Angola                  66      NaN                0.000000         64.0
# Angola                  67     8.33               23.965612         64.0
# Angola                  69     8.10               35.958573         77.0
# Angola                  75     8.06              239.891392         72.0
# ...                    ...      ...                     ...          ...
# Zimbabwe                27     4.36                0.000000         68.0
# Zimbabwe                26     4.06                0.000000          7.0
# Zimbabwe                25     4.43                0.000000         73.0
# Zimbabwe                25     1.72                0.000000         76.0
# Zimbabwe                24     1.68                0.000000         79.0
#
#              Measles    BMI   ...  Polio  Total expenditure  Diphtheria   \
# Country                       ...
# Afghanistan      6532   12.2  ...   24.0               8.20         24.0
# Angola            118   23.3  ...    7.0                NaN         64.0
# Angola          11699   22.7  ...   68.0               3.31         64.0
# Angola           8523   22.1  ...   67.0               4.26         77.0
# Angola           1449   21.0  ...   73.0               3.38         71.0
# ...               ...    ...  ...    ...                ...          ...
# Zimbabwe           31   27.1  ...   67.0               7.13         65.0
# Zimbabwe          998   26.7  ...    7.0               6.52         68.0
# Zimbabwe          304   26.3  ...   73.0               6.53         71.0
# Zimbabwe          529   25.9  ...   76.0               6.16         75.0
# Zimbabwe         1483   25.5  ...   78.0               7.10         78.0
#
#               HIV/AIDS          GDP  Population   thinness  1-19 years  \
# Country
# Afghanistan        0.1   114.560000    293756.0                    2.3
# Angola             1.9  3695.793748   2785935.0                    8.3
# Angola             2.0   479.312240   2692466.0                    8.5
# Angola             2.3   484.616884   2599834.0                    8.6
# Angola             2.5  4299.128890  24218565.0                    8.9
# ...                ...          ...         ...                    ...
# Zimbabwe          33.6   454.366654  12777511.0                    9.4
# Zimbabwe          36.7   453.351155  12633897.0                    9.8
# Zimbabwe          39.8    57.348340    125525.0                    1.2
# Zimbabwe          42.1   548.587312  12366165.0                    1.6
# Zimbabwe          43.5   547.358878  12222251.0                   11.0
#
#               thinness 5-9 years  Income composition of resources  Schooling
# Country
# Afghanistan                  2.5                            0.338        5.5
# Angola                       8.2                            0.531       11.4
# Angola                       8.3                            0.527       11.4
# Angola                       8.5                            0.523       11.4
# Angola                       8.8                            0.495        9.4
# ...                          ...                              ...        ...
# Zimbabwe                     9.4                            0.407        9.2
# Zimbabwe                     9.9                            0.418        9.5
# Zimbabwe                     1.3                            0.427       10.0
# Zimbabwe                     1.7                            0.427        9.8
# Zimbabwe                    11.2                            0.434        9.8
#
# [325 rows x 21 columns]

# %%
df.describe()
# Out:
#               Year  Life expectancy   Adult Mortality  infant deaths  \
# count  2938.000000       2928.000000      2928.000000    2938.000000
# mean   2007.518720         69.224932       164.796448      30.303948
# std       4.613841          9.523867       124.292079     117.926501
# min    2000.000000         36.300000         1.000000       0.000000
# 25%    2004.000000         63.100000        74.000000       0.000000
# 50%    2008.000000         72.100000       144.000000       3.000000
# 75%    2012.000000         75.700000       228.000000      22.000000
# max    2015.000000         89.000000       723.000000    1800.000000
#
#            Alcohol  percentage expenditure  Hepatitis B       Measles   \
# count  2744.000000             2938.000000  2385.000000    2938.000000
# mean      4.602861              738.251295    80.940461    2419.592240
# std       4.052413             1987.914858    25.070016   11467.272489
# min       0.010000                0.000000     1.000000       0.000000
# 25%       0.877500                4.685343    77.000000       0.000000
# 50%       3.755000               64.912906    92.000000      17.000000
# 75%       7.702500              441.534144    97.000000     360.250000
# max      17.870000            19479.911610    99.000000  212183.000000
#
#               BMI   under-five deaths         Polio  Total expenditure  \
# count  2904.000000         2938.000000  2919.000000         2712.00000
# mean     38.321247           42.035739    82.550188            5.93819
# std      20.044034          160.445548    23.428046            2.49832
# min       1.000000            0.000000     3.000000            0.37000
# 25%      19.300000            0.000000    78.000000            4.26000
# 50%      43.500000            4.000000    93.000000            5.75500
# 75%      56.200000           28.000000    97.000000            7.49250
# max      87.300000         2500.000000    99.000000           17.60000
#
#        Diphtheria      HIV/AIDS            GDP    Population  \
# count  2919.000000  2938.000000    2490.000000  2.286000e+03
# mean     82.324084     1.742103    7483.158469  1.275338e+07
# std      23.716912     5.077785   14270.169342  6.101210e+07
# min       2.000000     0.100000       1.681350  3.400000e+01
# 25%      78.000000     0.100000     463.935626  1.957932e+05
# 50%      93.000000     0.100000    1766.947595  1.386542e+06
# 75%      97.000000     0.800000    5910.806335  7.420359e+06
# max      99.000000    50.600000  119172.741800  1.293859e+09
#
#         thinness  1-19 years   thinness 5-9 years  \
# count            2904.000000          2904.000000
# mean                4.839704             4.870317
# std                 4.420195             4.508882
# min                 0.100000             0.100000
# 25%                 1.600000             1.500000
# 50%                 3.300000             3.300000
# 75%                 7.200000             7.200000
# max                27.700000            28.600000
#
#        Income composition of resources    Schooling
# count                      2771.000000  2775.000000
# mean                          0.627551    11.992793
# std                           0.210904     3.358920
# min                           0.000000     0.000000
# 25%                           0.493000    10.100000
# 50%                           0.677000    12.300000
# 75%                           0.779000    14.300000
# max                           0.948000    20.700000

# %%
df.isna().sum()
# Out:
# Year                                 0
# Status                               0
# Life expectancy                     10
# Adult Mortality                     10
# infant deaths                        0
# Alcohol                            194
# percentage expenditure               0
# Hepatitis B                        553
# Measles                              0
#  BMI                                34
# under-five deaths                    0
# Polio                               19
# Total expenditure                  226
# Diphtheria                          19
#  HIV/AIDS                            0
# GDP                                448
# Population                         652
#  thinness  1-19 years               34
#  thinness 5-9 years                 34
# Income composition of resources    167
# Schooling                          163
# dtype: int64

# %%
life_expectancy =  df["Life expectancy "]
life_expectancy
# Out:
# Country
# Afghanistan    65.0
# Afghanistan    59.9
# Afghanistan    59.9
# Afghanistan    59.5
# Afghanistan    59.2
#                ...
# Zimbabwe       44.3
# Zimbabwe       44.5
# Zimbabwe       44.8
# Zimbabwe       45.3
# Zimbabwe       46.0
# Name: Life expectancy , Length: 2938, dtype: float64

# %%
life_expectancy.index
# Out:
# Index(['Afghanistan', 'Afghanistan', 'Afghanistan', 'Afghanistan',
#        'Afghanistan', 'Afghanistan', 'Afghanistan', 'Afghanistan',
#        'Afghanistan', 'Afghanistan',
#        ...
#        'Zimbabwe', 'Zimbabwe', 'Zimbabwe', 'Zimbabwe', 'Zimbabwe', 'Zimbabwe',
#        'Zimbabwe', 'Zimbabwe', 'Zimbabwe', 'Zimbabwe'],
#       dtype='object', name='Country', length=2938)

# %%
life_expectancy.values
# Out:
# array([65. , 59.9, 59.9, ..., 44.8, 45.3, 46. ])

# %%
life_expectancy.to_numpy()
# Out:
# array([65. , 59.9, 59.9, ..., 44.8, 45.3, 46. ])

# %%
life_expectancy.to_numpy()
# Out:
# array([65. , 59.9, 59.9, ..., 44.8, 45.3, 46. ])

# %%
life_expectancy.dtype
# Out:
# dtype('float64')

# %%
life_expectancy.shape
# Out:
# (2938,)

# %%
life_expectancy.ndim
# Out:
# 1

# %%
life_expectancy.size
# Out:
# 2938

# %%
# df.T transpose
df.describe().T
# Out:
#                                   count          mean           std  \
# Year                             2938.0  2.007519e+03  4.613841e+00
# Life expectancy                  2928.0  6.922493e+01  9.523867e+00
# Adult Mortality                  2928.0  1.647964e+02  1.242921e+02
# infant deaths                    2938.0  3.030395e+01  1.179265e+02
# Alcohol                          2744.0  4.602861e+00  4.052413e+00
# percentage expenditure           2938.0  7.382513e+02  1.987915e+03
# Hepatitis B                      2385.0  8.094046e+01  2.507002e+01
# Measles                          2938.0  2.419592e+03  1.146727e+04
#  BMI                             2904.0  3.832125e+01  2.004403e+01
# under-five deaths                2938.0  4.203574e+01  1.604455e+02
# Polio                            2919.0  8.255019e+01  2.342805e+01
# Total expenditure                2712.0  5.938190e+00  2.498320e+00
# Diphtheria                       2919.0  8.232408e+01  2.371691e+01
#  HIV/AIDS                        2938.0  1.742103e+00  5.077785e+00
# GDP                              2490.0  7.483158e+03  1.427017e+04
# Population                       2286.0  1.275338e+07  6.101210e+07
#  thinness  1-19 years            2904.0  4.839704e+00  4.420195e+00
#  thinness 5-9 years              2904.0  4.870317e+00  4.508882e+00
# Income composition of resources  2771.0  6.275511e-01  2.109036e-01
# Schooling                        2775.0  1.199279e+01  3.358920e+00
#
#                                         min            25%           50%  \
# Year                             2000.00000    2004.000000  2.008000e+03
# Life expectancy                    36.30000      63.100000  7.210000e+01
# Adult Mortality                     1.00000      74.000000  1.440000e+02
# infant deaths                       0.00000       0.000000  3.000000e+00
# Alcohol                             0.01000       0.877500  3.755000e+00
# percentage expenditure              0.00000       4.685343  6.491291e+01
# Hepatitis B                         1.00000      77.000000  9.200000e+01
# Measles                             0.00000       0.000000  1.700000e+01
#  BMI                                1.00000      19.300000  4.350000e+01
# under-five deaths                   0.00000       0.000000  4.000000e+00
# Polio                               3.00000      78.000000  9.300000e+01
# Total expenditure                   0.37000       4.260000  5.755000e+00
# Diphtheria                          2.00000      78.000000  9.300000e+01
#  HIV/AIDS                           0.10000       0.100000  1.000000e-01
# GDP                                 1.68135     463.935626  1.766948e+03
# Population                         34.00000  195793.250000  1.386542e+06
#  thinness  1-19 years               0.10000       1.600000  3.300000e+00
#  thinness 5-9 years                 0.10000       1.500000  3.300000e+00
# Income composition of resources     0.00000       0.493000  6.770000e-01
# Schooling                           0.00000      10.100000  1.230000e+01
#
#                                           75%           max
# Year                             2.012000e+03  2.015000e+03
# Life expectancy                  7.570000e+01  8.900000e+01
# Adult Mortality                  2.280000e+02  7.230000e+02
# infant deaths                    2.200000e+01  1.800000e+03
# Alcohol                          7.702500e+00  1.787000e+01
# percentage expenditure           4.415341e+02  1.947991e+04
# Hepatitis B                      9.700000e+01  9.900000e+01
# Measles                          3.602500e+02  2.121830e+05
#  BMI                             5.620000e+01  8.730000e+01
# under-five deaths                2.800000e+01  2.500000e+03
# Polio                            9.700000e+01  9.900000e+01
# Total expenditure                7.492500e+00  1.760000e+01
# Diphtheria                       9.700000e+01  9.900000e+01
#  HIV/AIDS                        8.000000e-01  5.060000e+01
# GDP                              5.910806e+03  1.191727e+05
# Population                       7.420359e+06  1.293859e+09
#  thinness  1-19 years            7.200000e+00  2.770000e+01
#  thinness 5-9 years              7.200000e+00  2.860000e+01
# Income composition of resources  7.790000e-01  9.480000e-01
# Schooling                        1.430000e+01  2.070000e+01

# %%
life_expectancy.name
# Out:
# 'Life expectancy '

# %%
life_expectancy
# Out:
# Country
# Afghanistan    65.0
# Afghanistan    59.9
# Afghanistan    59.9
# Afghanistan    59.5
# Afghanistan    59.2
#                ...
# Zimbabwe       44.3
# Zimbabwe       44.5
# Zimbabwe       44.8
# Zimbabwe       45.3
# Zimbabwe       46.0
# Name: Life expectancy , Length: 2938, dtype: float64

# %%
life_expectancy.rename({"Afghanistan":"Afgan"})
# Out:
# Country
# Afgan       65.0
# Afgan       59.9
# Afgan       59.9
# Afgan       59.5
# Afgan       59.2
#             ...
# Zimbabwe    44.3
# Zimbabwe    44.5
# Zimbabwe    44.8
# Zimbabwe    45.3
# Zimbabwe    46.0
# Name: Life expectancy , Length: 2938, dtype: float64

# %%
life_expectancy.memory_usage()/1024
# Out:
# 110.4453125

# %%
life_expectancy.dropna()
# Out:
# 10

# %%
life_expectancy.dropna().astype(np.int8).memory_usage()/1024
# Out:
# 25.734375

# %%
life_expectancy.size
# Out:
# 2938

# %%
life_expectancy.dropna().size
# Out:
# 2928

# %%
life_expectancy.dropna().astype(np.int8)
# Out:
# Country
# Afghanistan    65
# Afghanistan    59
# Afghanistan    59
# Afghanistan    59
# Afghanistan    59
#                ..
# Zimbabwe       44
# Zimbabwe       44
# Zimbabwe       44
# Zimbabwe       45
# Zimbabwe       46
# Name: Life expectancy , Length: 2928, dtype: int8

# %%
a = (life_expectancy<40)

# %%
df.iat[0,0]
# Out:
# 2015

# %%
df.at["Zimbabwe","Life expectancy "]
# Out:
# Country
# Zimbabwe    67.0
# Zimbabwe    59.2
# Zimbabwe    58.0
# Zimbabwe    56.6
# Zimbabwe    54.9
# Zimbabwe    52.4
# Zimbabwe    50.0
# Zimbabwe    48.2
# Zimbabwe    46.6
# Zimbabwe    45.4
# Zimbabwe    44.6
# Zimbabwe    44.3
# Zimbabwe    44.5
# Zimbabwe    44.8
# Zimbabwe    45.3
# Zimbabwe    46.0
# Name: Life expectancy , dtype: float64

# %%
df.loc["Zimbabwe"]
# Out:
#           Year      Status  Life expectancy   Adult Mortality  infant deaths  \
# Country
# Zimbabwe  2015  Developing              67.0            336.0             22
# Zimbabwe  2014  Developing              59.2            371.0             23
# Zimbabwe  2013  Developing              58.0            399.0             25
# Zimbabwe  2012  Developing              56.6            429.0             26
# Zimbabwe  2011  Developing              54.9            464.0             28
# Zimbabwe  2010  Developing              52.4            527.0             29
# Zimbabwe  2009  Developing              50.0            587.0             30
# Zimbabwe  2008  Developing              48.2            632.0             30
# Zimbabwe  2007  Developing              46.6             67.0             29
# Zimbabwe  2006  Developing              45.4              7.0             28
# Zimbabwe  2005  Developing              44.6            717.0             28
# Zimbabwe  2004  Developing              44.3            723.0             27
# Zimbabwe  2003  Developing              44.5            715.0             26
# Zimbabwe  2002  Developing              44.8             73.0             25
# Zimbabwe  2001  Developing              45.3            686.0             25
# Zimbabwe  2000  Developing              46.0            665.0             24
#
#           Alcohol  percentage expenditure  Hepatitis B  Measles    BMI   ...  \
# Country                                                                  ...
# Zimbabwe      NaN                0.000000         87.0         0   31.8  ...
# Zimbabwe     6.50               10.822595         91.0         0   31.3  ...
# Zimbabwe     6.39               10.666707         95.0         0    3.8  ...
# Zimbabwe     6.09               92.602336         97.0         0    3.3  ...
# Zimbabwe     6.00               63.750530         94.0         0   29.9  ...
# Zimbabwe     5.21               53.308581          9.0      9696   29.4  ...
# Zimbabwe     4.64                1.040021         73.0       853   29.0  ...
# Zimbabwe     3.56               20.843429         75.0         0   28.6  ...
# Zimbabwe     3.88               29.814566         72.0       242   28.2  ...
# Zimbabwe     4.57               34.262169         68.0       212   27.9  ...
# Zimbabwe     4.14                8.717409         65.0       420   27.5  ...
# Zimbabwe     4.36                0.000000         68.0        31   27.1  ...
# Zimbabwe     4.06                0.000000          7.0       998   26.7  ...
# Zimbabwe     4.43                0.000000         73.0       304   26.3  ...
# Zimbabwe     1.72                0.000000         76.0       529   25.9  ...
# Zimbabwe     1.68                0.000000         79.0      1483   25.5  ...
#
#           Polio  Total expenditure  Diphtheria    HIV/AIDS         GDP  \
# Country
# Zimbabwe   88.0                NaN         87.0        6.2  118.693830
# Zimbabwe   92.0               6.44         91.0        6.3  127.474620
# Zimbabwe   95.0               6.88         95.0        6.8  111.227396
# Zimbabwe   95.0               6.69         95.0        8.8  955.648466
# Zimbabwe   93.0               6.31         93.0       13.3  839.927936
# Zimbabwe   89.0               5.37         89.0       15.7  713.635620
# Zimbabwe   69.0               6.26         73.0       18.1   65.824121
# Zimbabwe   75.0               4.96         75.0       20.5  325.678573
# Zimbabwe   73.0               4.47         73.0       23.7  396.998217
# Zimbabwe   71.0               5.12          7.0       26.8  414.796232
# Zimbabwe   69.0               6.44         68.0       30.3  444.765750
# Zimbabwe   67.0               7.13         65.0       33.6  454.366654
# Zimbabwe    7.0               6.52         68.0       36.7  453.351155
# Zimbabwe   73.0               6.53         71.0       39.8   57.348340
# Zimbabwe   76.0               6.16         75.0       42.1  548.587312
# Zimbabwe   78.0               7.10         78.0       43.5  547.358878
#
#           Population   thinness  1-19 years   thinness 5-9 years  \
# Country
# Zimbabwe  15777451.0                    5.6                  5.5
# Zimbabwe  15411675.0                    5.9                  5.7
# Zimbabwe    155456.0                    6.2                  6.0
# Zimbabwe   1471826.0                    6.5                  6.4
# Zimbabwe  14386649.0                    6.8                  6.7
# Zimbabwe   1486317.0                    7.1                  7.0
# Zimbabwe   1381599.0                    7.5                  7.4
# Zimbabwe  13558469.0                    7.8                  7.8
# Zimbabwe   1332999.0                    8.2                  8.2
# Zimbabwe  13124267.0                    8.6                  8.6
# Zimbabwe    129432.0                    9.0                  9.0
# Zimbabwe  12777511.0                    9.4                  9.4
# Zimbabwe  12633897.0                    9.8                  9.9
# Zimbabwe    125525.0                    1.2                  1.3
# Zimbabwe  12366165.0                    1.6                  1.7
# Zimbabwe  12222251.0                   11.0                 11.2
#
#           Income composition of resources  Schooling
# Country
# Zimbabwe                            0.507       10.3
# Zimbabwe                            0.498       10.3
# Zimbabwe                            0.488       10.4
# Zimbabwe                            0.464        9.8
# Zimbabwe                            0.452       10.1
# Zimbabwe                            0.436       10.0
# Zimbabwe                            0.419        9.9
# Zimbabwe                            0.421        9.7
# Zimbabwe                            0.414        9.6
# Zimbabwe                            0.408        9.5
# Zimbabwe                            0.406        9.3
# Zimbabwe                            0.407        9.2
# Zimbabwe                            0.418        9.5
# Zimbabwe                            0.427       10.0
# Zimbabwe                            0.427        9.8
# Zimbabwe                            0.434        9.8
#
# [16 rows x 21 columns]
