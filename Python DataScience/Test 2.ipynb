# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("./datasets/Life Expectancy Data.csv")

# %%
df.head()
# Out:
#        Country  Year      Status  Life expectancy   Adult Mortality  \
# 0  Afghanistan  2015  Developing              65.0            263.0
# 1  Afghanistan  2014  Developing              59.9            271.0
# 2  Afghanistan  2013  Developing              59.9            268.0
# 3  Afghanistan  2012  Developing              59.5            272.0
# 4  Afghanistan  2011  Developing              59.2            275.0
#
#    infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   ...  \
# 0             62     0.01               71.279624         65.0      1154  ...
# 1             64     0.01               73.523582         62.0       492  ...
# 2             66     0.01               73.219243         64.0       430  ...
# 3             69     0.01               78.184215         67.0      2787  ...
# 4             71     0.01                7.097109         68.0      3013  ...
#
#    Polio  Total expenditure  Diphtheria    HIV/AIDS         GDP  Population  \
# ...

# %%
df.columns = [col.strip() for col in df.columns]

# %%
df[["Life expectancy", "Adult Mortality"]].mean()
# Out:
# Life expectancy     69.224932
# Adult Mortality    164.796448
# dtype: float64

# %%
df[["Life expectancy", "Adult Mortality"]] - df[["Life expectancy", "Adult Mortality"]].mean()
# Out:
#       Life expectancy  Adult Mortality
# 0           -4.224932        98.203552
# 1           -9.324932       106.203552
# 2           -9.324932       103.203552
# 3           -9.724932       107.203552
# 4          -10.024932       110.203552
# ...               ...              ...
# 2933       -24.924932       558.203552
# 2934       -24.724932       550.203552
# 2935       -24.424932       -91.796448
# 2936       -23.924932       521.203552
# 2937       -23.224932       500.203552
#
# [2938 rows x 2 columns]

# %%
import matplotlib.pyplot as plt

# %%
fig, axes = plt.subplots(figsize=(15, 5))

labels = np.arange(len(df.columns))

axes.bar(labels, df.isna().sum())

axes.set_xticks(labels)
axes.set_xticklabels(df.columns)

axes.tick_params(axis='x', rotation=90)
plt.show()

# %%
df[df["Population"].isna()]
# Out:
#                   Country  Year      Status  Life expectancy  Adult Mortality  \
# 64    Antigua and Barbuda  2015  Developing             76.4             13.0
# 65    Antigua and Barbuda  2014  Developing             76.2            131.0
# 66    Antigua and Barbuda  2013  Developing             76.1            133.0
# 67    Antigua and Barbuda  2012  Developing             75.9            134.0
# 68    Antigua and Barbuda  2011  Developing             75.7            136.0
# ...                   ...   ...         ...              ...              ...
# 2901                Yemen  2004  Developing             62.2            247.0
# 2902                Yemen  2003  Developing             61.9            249.0
# 2903                Yemen  2002  Developing             61.5             25.0
# 2904                Yemen  2001  Developing             61.1            251.0
# 2905                Yemen  2000  Developing             68.0            252.0
#
# ...

# %%
na_group = df[df["Population"].isna()].groupby("Country")

# %%
na_group.groups.keys()
# Out:
# dict_keys(['Antigua and Barbuda', 'Bahamas', 'Bahrain', 'Barbados', 'Bolivia (Plurinational State of)', 'Brunei Darussalam', 'Congo', 'Cook Islands', 'Cuba', 'Czechia', "Côte d'Ivoire", "Democratic People's Republic of Korea", 'Democratic Republic of the Congo', 'Dominica', 'Egypt', 'Eritrea', 'Gambia', 'Grenada', 'Iran (Islamic Republic of)', 'Kuwait', 'Kyrgyzstan', "Lao People's Democratic Republic", 'Libya', 'Marshall Islands', 'Micronesia (Federated States of)', 'Monaco', 'Nauru', 'New Zealand', 'Niue', 'Oman', 'Qatar', 'Republic of Korea', 'Republic of Moldova', 'Saint Kitts and Nevis', 'Saint Lucia', 'Saint Vincent and the Grenadines', 'San Marino', 'Saudi Arabia', 'Singapore', 'Slovakia', 'Somalia', 'The former Yugoslav republic of Macedonia', 'United Arab Emirates', 'United Kingdom of Great Britain and Northern Ireland', 'United Republic of Tanzania', 'United States of America', 'Venezuela (Bolivarian Republic of)', 'Viet Nam', 'Yemen'])

# %%
df.groupby("Country").get_group("Gambia").shape
# Out:
# (16, 22)

# %%
country_group = df.groupby("Country")

# %%
nan_summary =  country_group.apply(lambda x: x.isna().sum())
nan_summary
# Out:
#                                     Country  Year  Status  Life expectancy  \
# Country
# Afghanistan                               0     0       0                0
# Albania                                   0     0       0                0
# Algeria                                   0     0       0                0
# Angola                                    0     0       0                0
# Antigua and Barbuda                       0     0       0                0
# ...                                     ...   ...     ...              ...
# Venezuela (Bolivarian Republic of)        0     0       0                0
# Viet Nam                                  0     0       0                0
# Yemen                                     0     0       0                0
# Zambia                                    0     0       0                0
# Zimbabwe                                  0     0       0                0
#
# ...

# %%
count_summary =  country_group.apply(lambda x: x.count())
count_summary
# Out:
#                                     Country  Year  Status  Life expectancy  \
# Country
# Afghanistan                              16    16      16               16
# Albania                                  16    16      16               16
# Algeria                                  16    16      16               16
# Angola                                   16    16      16               16
# Antigua and Barbuda                      16    16      16               16
# ...                                     ...   ...     ...              ...
# Venezuela (Bolivarian Republic of)       16    16      16               16
# Viet Nam                                 16    16      16               16
# Yemen                                    16    16      16               16
# Zambia                                   16    16      16               16
# Zimbabwe                                 16    16      16               16
#
# ...

# %%
all_counts = nan_summary+ count_summary

# %%
all_counts
# Out:
#                                     Country  Year  Status  Life expectancy  \
# Country
# Afghanistan                              16    16      16               16
# Albania                                  16    16      16               16
# Algeria                                  16    16      16               16
# Angola                                   16    16      16               16
# Antigua and Barbuda                      16    16      16               16
# ...                                     ...   ...     ...              ...
# Venezuela (Bolivarian Republic of)       16    16      16               16
# Viet Nam                                 16    16      16               16
# Yemen                                    16    16      16               16
# Zambia                                   16    16      16               16
# Zimbabwe                                 16    16      16               16
#
# ...

# %%
nan_proportion = nan_summary/ all_counts
inan_proportion = count_summary / all_counts

# %%
nan_proportion
# Out:
#                                     Country  Year  Status  Life expectancy  \
# Country
# Afghanistan                             0.0   0.0     0.0              0.0
# Albania                                 0.0   0.0     0.0              0.0
# Algeria                                 0.0   0.0     0.0              0.0
# Angola                                  0.0   0.0     0.0              0.0
# Antigua and Barbuda                     0.0   0.0     0.0              0.0
# ...                                     ...   ...     ...              ...
# Venezuela (Bolivarian Republic of)      0.0   0.0     0.0              0.0
# Viet Nam                                0.0   0.0     0.0              0.0
# Yemen                                   0.0   0.0     0.0              0.0
# Zambia                                  0.0   0.0     0.0              0.0
# Zimbabwe                                0.0   0.0     0.0              0.0
#
# ...

# %%
inan_proportion
# Out:
#                                     Country  Year  Status  Life expectancy  \
# Country
# Afghanistan                             1.0   1.0     1.0              1.0
# Albania                                 1.0   1.0     1.0              1.0
# Algeria                                 1.0   1.0     1.0              1.0
# Angola                                  1.0   1.0     1.0              1.0
# Antigua and Barbuda                     1.0   1.0     1.0              1.0
# ...                                     ...   ...     ...              ...
# Venezuela (Bolivarian Republic of)      1.0   1.0     1.0              1.0
# Viet Nam                                1.0   1.0     1.0              1.0
# Yemen                                   1.0   1.0     1.0              1.0
# Zambia                                  1.0   1.0     1.0              1.0
# Zimbabwe                                1.0   1.0     1.0              1.0
#
# ...
