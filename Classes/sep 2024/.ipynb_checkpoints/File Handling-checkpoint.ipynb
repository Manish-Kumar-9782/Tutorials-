# %% [markdown]
# ## File Handling

# %%
# relative file path
file_path =  "./files/test.txt"

# %%
file = open(file_path)

# %%
file.readable()
# Out:
# True

# %%
file.readline()
# Out:
# 'Hello World !...\n'

# %%
file.readline()
# Out:
# 'Good Morining ...!\n'

# %%
file.readline()
# Out:
# 'Have a good day.'

# %%
file.readline()
# Out:
# ''

# %%
file = open(file_path)

# %%
bool('')
# Out:
# False

# %%
file = open(file_path)
isEof = False ## until we don't reach to the end of the file.
# false: it means we have some content to read.

while not isEof:
    line = file.readline()
    isEof = not bool(line)
    print(line, end="")
# Out:
# Hello World !...
# Good Morining ...!
# Have a good day.

# %%
file.readlines()
# Out:
# []

# %%
file = open(file_path)
file.readlines()
# Out:
# ['Hello World !...\n', 'Good Morining ...!\n', 'Have a good day.']

# %%
file.close()

# %%
file.closed
# Out:
# True

# %% [markdown]
# **write file mode**

# %%
file = open(file_path, mode="w")

# %%
file.readable()
# Out:
# False

# %%
file.writable()
# Out:
# True

# %%
file.write("I am having fun...! You should join me...")
# Out:
# 41

# %%
file.close()

# %%
file = open(file_path)
isEof = False ## until we don't reach to the end of the file.
# false: it means we have some content to read.

while not isEof:
    line = file.readline()
    isEof = not bool(line)
    print(line, end="")
# Out:
# I am having fun...! You should join me...
